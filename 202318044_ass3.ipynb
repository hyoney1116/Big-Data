# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      |▍
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#      |████████████████████████████████| 317.0 MB 6.2 kB/s
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 9.6 MB/s
# Building wheels for collected packages: pyspark
# done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488511 sha256=3b0152a6309fbc6e0d34032c790425e224dadbd6e90412603e7a47918ba02fd1
#   Stored in directory: /root/.cache/pip/wheels/92/09/11/aa01d01a7f005fda8a66ad71d2be7f8aa341bddafb27eee3c7
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.7 pyspark-3.5.1
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-c09ed35a-1bbc-4817-8835-96a141064ce8/bin/python -m pip install --upgrade pip' command.

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

# %%
sc = SparkContext.getOrCreate()
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=6949490536245280#setting/sparkui/0228-175604-u376u6gp/driver-6008723166709976616">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
rdd = spark.sparkContext.textFile("/content/drive/MyDrive/Dataset/sample.txt") # RDD created
path='dbfs:/FileStore/shared_uploads/202318044@daiict.ac.in/SampleTextFile_50kb-1.txt'
rdd = spark.sparkContext.textFile(path)

# %%
data = rdd.collect()

# %%
import re
pattern = r'[\n\s!@#$%^&*\(\)\{\}\[\]~`/\?<>,\.]+'
words = re.split(pattern, str(data))
words
# Out:
# Out[7]: ['',
#  "'Lorem",
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet',
#  'consectetur',
#  'adipiscing',
#  'elit',
#  'Vivamus',
#  'condimentum',
#  'sagittis',
#  'lacus',
#  'laoreet',
#  'luctus',
#  'ligula',
#  'laoreet',
#  'ut',
#  'Vestibulum',
#  'ullamcorper',
#  'accumsan',
#  'velit',
#  'vel',
#  'vehicula',
#  'Proin',
#  'tempor',
#  'lacus',
#  'arcu',
#  'Nunc',
#  'at',
#  'elit',
#  'condimentum',
#  'semper',
#  'nisi',
#  'et',
#  'condimentum',
#  'mi',
#  'In',
#  'venenatis',
#  'blandit',
#  'nibh',
#  'at',
#  'sollicitudin',
#  'Vestibulum',
#  'dapibus',
#  'mauris',
#  'at',
#  'orci',
#  'maximus',
#  'pellentesque',
#  'Nullam',
#  'id',
#  'elementum',
#  'ipsum',
#  'Suspendisse',
#  'cursus',
#  'lobortis',
#  'viverra',
#  'Proin',
#  'et',
#  'erat',
#  'at',
#  'mauris',
#  'tincidunt',
#  'porttitor',
#  'vitae',
#  'ac',
#  'dui',
#  "'",
#  "''",
#  "'Donec",
#  'vulputate',
#  'lorem',
#  'tortor',
#  'nec',
#  'fermentum',
#  'nibh',
#  'bibendum',
#  'vel',
#  'Lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet',
#  'consectetur',
#  'adipiscing',
#  'elit',
#  'Praesent',
#  'dictum',
#  'luctus',
#  'massa',
#  'non',
#  'euismod',
#  'lacus',
#  'Pellentesque',
#  'condimentum',
#  'dolor',
#  'est',
#  'ut',
#  'dapibus',
#  'lectus',
#  'luctus',
#  'ac',
#  'Ut',
#  'sagittis',
#  'commodo',
#  'arcu',
#  'Integer',
#  'nisi',
#  'nulla',
#  'facilisis',
#  'sit',
#  'amet',
#  'nulla',
#  'quis',
#  'eleifend',
#  'suscipit',
#  'purus',
#  'Class',
#  'aptent',
#  'taciti',
#  'sociosqu',
#  'ad',
#  'litora',
#  'torquent',
#  'per',
#  'conubia',
#  'nostra',
#  'per',
#  'inceptos',
#  'himenaeos',
#  'Aliquam',
#  'euismod',
#  'ultrices',
#  'lorem',
#  'sit',
#  'amet',
#  'imperdiet',
#  'est',
#  'tincidunt',
#  'vel',
#  'Phasellus',
#  'dictum',
#  'justo',
#  'sit',
#  'amet',
#  'ligula',
#  'varius',
#  'aliquet',
#  'auctor',
#  'et',
#  'metus',
#  'Fusce',
#  'vitae',
#  'tortor',
#  'et',
#  'nisi',
#  'pulvinar',
#  'vestibulum',
#  'eget',
#  'in',
#  'risus',
#  'Donec',
#  'ante',
#  'ex',
#  'placerat',
#  'a',
#  'lorem',
#  'eget',
#  'ultricies',
#  'bibendum',
#  'purus',
#  'Nam',
#  'sit',
#  'amet',
#  'neque',
#  'non',
#  'ante',
#  'laoreet',
#  'rutrum',
#  'Nullam',
#  'aliquet',
#  'commodo',
#  'urna',
#  'sed',
#  'ullamcorper',
#  'odio',
#  'feugiat',
#  'id',
#  'Mauris',
#  'nisi',
#  'sapien',
#  'porttitor',
#  'in',
#  'condimentum',
#  'nec',
#  'venenatis',
#  'eu',
#  'urna',
#  'Pellentesque',
#  'feugiat',
#  'diam',
#  'est',
#  'at',
#  'rhoncus',
#  'orci',
#  'porttitor',
#  'non',
#  "'",
#  "''",
#  "'Nulla",
#  'luctus',
#  'sem',
#  'sit',
#  'amet',
#  'nisi',
#  'consequat',
#  'id',
#  'ornare',
#  'ipsum',
#  'dignissim',
#  'Sed',
#  'elementum',
#  'elit',
#  'nibh',
#  'eu',
#  'condimentum',
#  'orci',
#  'viverra',
#  'quis',
#  'Aenean',
#  'suscipit',
#  'vitae',
#  'felis',
#  'non',
#  'suscipit',
#  'Suspendisse',
#  'pharetra',
#  'turpis',
#  'non',
#  'eros',
#  'semper',
#  'dictum',
#  'Etiam',
#  'tincidunt',
#  'venenatis',
#  'venenatis',
#  'Praesent',
#  'eget',
#  'gravida',
#  'lorem',
#  'ut',
#  'congue',
#  'diam',
#  'Etiam',
#  'facilisis',
#  'elit',
#  'at',
#  'porttitor',
#  'egestas',
#  'Praesent',
#  'consequat',
#  'velit',
#  'non',
#  'vulputate',
#  'convallis',
#  'ligula',
#  'diam',
#  'sagittis',
#  'urna',
#  'in',
#  'venenatis',
#  'nisi',
#  'justo',
#  'ut',
#  'mauris',
#  'Vestibulum',
#  'posuere',
#  'sollicitudin',
#  'mi',
#  'et',
#  'vulputate',
#  'nisl',
#  'fringilla',
#  'non',
#  'Nulla',
#  'ornare',
#  'pretium',
#  'velit',
#  'a',
#  'euismod',
#  'Nunc',
#  'sagittis',
#  'venenatis',
#  'vestibulum',
#  'Nunc',
#  'sodales',
#  'libero',
#  'a',
#  'est',
#  'ornare',
#  'ultricies',
#  'Sed',
#  'sed',
#  'leo',
#  'sed',
#  'orci',
#  'pellentesque',
#  'ultrices',
#  'Mauris',
#  'sollicitudin',
#  'sem',
#  'quis',
#  'placerat',
#  'ornare',
#  'velit',
#  'arcu',
#  'convallis',
#  'ligula',
#  'pretium',
#  'finibus',
#  'nisl',
#  'sapien',
#  'vel',
#  'sem',
#  'Vivamus',
#  'sit',
#  'amet',
#  'tortor',
#  'id',
#  'lorem',
#  'consequat',
#  'hendrerit',
#  'Nullam',
#  'at',
#  'dui',
#  'risus',
#  "'",
#  "''",
#  "'Vestibulum",
#  'ante',
#  'ipsum',
#  'primis',
#  'in',
#  'faucibus',
#  'orci',
#  'luctus',
#  'et',
#  'ultrices',
#  'posuere',
#  'cubilia',
#  'Curae;',
#  'Lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet',
#  'consectetur',
#  'adipiscing',
#  'elit',
#  'Sed',
#  'feugiat',
#  'semper',
#  'velit',
#  'consequat',
#  'facilisis',
#  'Etiam',
#  'facilisis',
#  'justo',
#  'non',
#  'iaculis',
#  'dictum',
#  'Fusce',
#  'turpis',
#  'neque',
#  'pharetra',
#  'ut',
#  'odio',
#  'eu',
#  'hendrerit',
#  'rhoncus',
#  'lacus',
#  'Nunc',
#  'orci',
#  'felis',
#  'imperdiet',
#  'vel',
#  'interdum',
#  'quis',
#  'porta',
#  'eu',
#  'ipsum',
#  'Pellentesque',
#  'dictum',
#  'sem',
#  'lacinia',
#  'auctor',
#  'dui',
#  'in',
#  'malesuada',
#  'nunc',
#  'Maecenas',
#  'sit',
#  'amet',
#  'mollis',
#  'eros',
#  'Proin',
#  'fringilla',
#  'viverra',
#  'ligula',
#  'sollicitudin',
#  'viverra',
#  'ante',
#  'sollicitudin',
#  'congue',
#  'Donec',
#  'mollis',
#  'felis',
#  'eu',
#  'libero',
#  'malesuada',
#  'et',
#  'lacinia',
#  'risus',
#  'interdum',
#  "'",
#  "''",
#  "'Etiam",
#  'vitae',
#  'accumsan',
#  'augue',
#  'Ut',
#  'urna',
#  'orci',
#  'malesuada',
#  'ut',
#  'nisi',
#  'a',
#  'condimentum',
#  'gravida',
#  'magna',
#  'Nulla',
#  'bibendum',
#  'ex',
#  'in',
#  'vulputate',
#  'sagittis',
#  'Nulla',
#  'facilisi',
#  'Nullam',
#  'faucibus',
#  'et',
#  'metus',
#  'ac',
#  'consequat',
#  'Quisque',
#  'tempor',
#  'eros',
#  'velit',
#  'id',
#  'mattis',
#  'nibh',
#  'aliquet',
#  'a',
#  'Aenean',
#  'tempor',
#  'elit',
#  'ut',
#  'finibus',
#  'auctor',
#  'Sed',
#  'at',
#  'imperdiet',
#  'mauris',
#  'Vestibulum',
#  'pharetra',
#  'non',
#  'lacus',
#  'sed',
#  'pulvinar',
#  'Sed',
#  'pellentesque',
#  'magna',
#  'a',
#  'eros',
#  'volutpat',
#  'ullamcorper',
#  'In',
#  'hac',
#  'habitasse',
#  'platea',
#  'dictumst',
#  'Donec',
#  'ipsum',
#  'mi',
#  'feugiat',
#  'in',
#  'eros',
#  'sed',
#  'varius',
#  'lacinia',
#  'turpis',
#  'Donec',
#  'vulputate',
#  'tincidunt',
#  'dui',
#  'ac',
#  'laoreet',
#  'Sed',
#  'in',
#  'eros',
#  'dui',
#  'Pellentesque',
#  'placerat',
#  'tristique',
#  'ligula',
#  'eu',
#  'finibus',
#  'Proin',
#  'nec',
#  'faucibus',
#  'felis',
#  'eu',
#  'commodo',
#  'ipsum',
#  "'",
#  "''",
#  "'Integer",
#  'eu',
#  'hendrerit',
#  'diam',
#  'sed',
#  'consectetur',
#  'nunc',
#  'Aliquam',
#  'a',
#  'sem',
#  'vitae',
#  'leo',
#  'fermentum',
#  'faucibus',
#  'quis',
#  'at',
#  'sem',
#  'Etiam',
#  'blandit',
#  'quam',
#  'quis',
#  'fermentum',
#  'varius',
#  'ante',
#  'urna',
#  'ultricies',
#  'lectus',
#  'vel',
#  'pellentesque',
#  'ligula',
#  'arcu',
#  'nec',
#  'elit',
#  'Donec',
#  'placerat',
#  'ante',
#  'in',
#  'enim',
#  'scelerisque',
#  'pretium',
#  'Donec',
#  'et',
#  'rhoncus',
#  'erat',
#  'Aenean',
#  'tempor',
#  'nisi',
#  'vitae',
#  'augue',
#  'tincidunt',
#  'luctus',
#  'Nam',
#  'condimentum',
#  'dictum',
#  'ante',
#  'et',
#  'laoreet',
#  'neque',
#  'pellentesque',
#  'id',
#  'Curabitur',
#  'consectetur',
#  'cursus',
#  'neque',
#  'aliquam',
#  'porta',
#  'Ut',
#  'interdum',
#  'nunc',
#  'nec',
#  'nibh',
#  'vestibulum',
#  'in',
#  'sagittis',
#  'metus',
#  'facilisis',
#  'Pellentesque',
#  'feugiat',
#  'condimentum',
#  'metus',
#  'Etiam',
#  'venenatis',
#  'quam',
#  'at',
#  'ante',
#  'rhoncus',
#  'vestibulum',
#  'Maecenas',
#  'suscipit',
#  'congue',
#  'pellentesque',
#  'Vestibulum',
#  'suscipit',
#  'scelerisque',
#  'fermentum',
#  'Nulla',
#  'iaculis',
#  'risus',
#  'ac',
#  'vulputate',
#  'porttitor',
#  "'",
#  "''",
#  "'Mauris",
#  'nec',
#  'metus',
#  'vel',
#  'dolor',
#  'blandit',
#  'faucibus',
#  'et',
#  'vel',
#  'magna',
#  'Ut',
#  'tincidunt',
#  'ipsum',
#  'non',
#  'nunc',
#  'dapibus',
#  'sed',
#  'blandit',
#  'mi',
#  'condimentum',
#  'Quisque',
#  'pharetra',
#  'interdum',
#  'quam',
#  'nec',
#  'feugiat',
#  'Sed',
#  'pellentesque',
#  'nulla',
#  'et',
#  'turpis',
#  'blandit',
#  'interdum',
#  'Curabitur',
#  'at',
#  'metus',
#  'vitae',
#  'augue',
#  'elementum',
#  'viverra',
#  'Sed',
#  'mattis',
#  'lorem',
#  'non',
#  'enim',
#  'fermentum',
#  'finibus',
#  'Sed',
#  'at',
#  'dui',
#  'in',
#  'magna',
#  'dignissim',
#  'accumsan',
#  'Proin',
#  'tincidunt',
#  'ultricies',
#  'cursus',
#  'Maecenas',
#  'tincidunt',
#  'magna',
#  'at',
#  'urna',
#  'faucibus',
#  'lacinia',
#  "'",
#  "''",
#  "'Quisque",
#  'venenatis',
#  'justo',
#  'sit',
#  'amet',
#  'tortor',
#  'condimentum',
#  'nec',
#  'tincidunt',
#  'tellus',
#  'viverra',
#  'Morbi',
#  'risus',
#  'ipsum',
#  'consequat',
#  'convallis',
#  'malesuada',
#  'non',
#  'fermentum',
#  'non',
#  'velit',
#  'Nulla',
#  'facilisis',
#  'orci',
#  'eget',
#  'ligula',
#  'mattis',
#  'fermentum',
#  'Aliquam',
#  'vel',
#  'velit',
#  'ultricies',
#  'sollicitudin',
#  'nibh',
#  'eu',
#  'congue',
#  'velit',
#  'Donec',
#  'nulla',
#  'lorem',
#  'euismod',
#  'id',
#  'cursus',
#  'at',
#  'sollicitudin',
#  'et',
#  'arcu',
#  'Proin',
#  'vitae',
#  'tincidunt',
#  'ipsum',
#  'Vivamus',
#  'elementum',
#  'eleifend',
#  'justo',
#  'placerat',
#  'interdum',
#  'nulla',
#  'rutrum',
#  'id',
#  "'",
#  "''",
#  "'Phasellus",
#  'fringilla',
#  'luctus',
#  'magna',
#  'a',
#  'finibus',
#  'justo',
#  'dapibus',
#  'a',
#  'Nam',
#  'risus',
#  'felis',
#  'rhoncus',
#  'eget',
#  'diam',
#  'sit',
#  'amet',
#  'congue',
#  'facilisis',
#  'nibh',
#  'Interdum',
#  'et',
#  'malesuada',
#  'fames',
#  'ac',
#  'ante',
#  'ipsum',
#  'primis',
#  'in',
#  'faucibus',
#  'Praesent',
#  'consequat',
#  'euismod',
#  'diam',
#  'eget',
#  'volutpat',
#  'magna',
#  'convallis',
#  'at',
#  'Mauris',
#  'placerat',
#  'pellentesque',
#  'imperdiet',
#  'Nulla',
#  'porta',
#  'scelerisque',
#  'enim',
#  'et',
#  'scelerisque',
#  'neque',
#  'bibendum',
#  'in',
#  'Proin',
#  'eget',
#  'turpis',
#  'nisi',
#  'Suspendisse',
#  'ut',
#  'est',
#  'a',
#  'erat',
#  'egestas',
#  'eleifend',
#  'at',
#  'euismod',
#  'arcu',
#  'Donec',
#  'aliquet',
#  'nisi',
#  'sed',
#  'faucibus',
#  'condimentum',
#  'nisi',
#  'metus',
#  'dictum',
#  'eros',
#  'nec',
#  'dignissim',
#  'justo',
#  'odio',
#  'id',
#  'nulla',
#  'Pellentesque',
#  'habitant',
#  'morbi',
#  'tristique',
#  'senectus',
#  'et',
#  'netus',
#  'et',
#  'malesuada',
#  'fames',
#  'ac',
#  'turpis',
#  'egestas',
#  'Maecenas',
#  'sollicitudin',
#  'justo',
#  'id',
#  'elementum',
#  'eleifend',
#  'justo',
#  'neque',
#  'aliquet',
#  'nibh',
#  'finibus',
#  'malesuada',
#  'metus',
#  'erat',
#  'eget',
#  'neque',
#  'Suspendisse',
#  'nec',
#  'auctor',
#  'orci',
#  'Aenean',
#  'et',
#  'vestibulum',
#  'nulla',
#  'Nullam',
#  'hendrerit',
#  'augue',
#  'tristique',
#  'commodo',
#  'metus',
#  'id',
#  'sodales',
#  'lorem',
#  'Etiam',
#  'feugiat',
#  'dui',
#  'est',
#  'vitae',
#  'auctor',
#  'risus',
#  'convallis',
#  'non',
#  "'",
#  "''",
#  "'Maecenas",
#  'turpis',
#  'enim',
#  'consectetur',
#  'eget',
#  'lectus',
#  'eu',
#  'hendrerit',
#  'posuere',
#  'lacus',
#  'Praesent',
#  'efficitur',
#  'felis',
#  'eget',
#  'dapibus',
#  'consectetur',
#  'nisi',
#  'massa',
#  'dignissim',
#  'enim',
#  'nec',
#  'semper',
#  'dolor',
#  'est',
#  'eu',
#  'urna',
#  'Nullam',
#  'ut',
#  'sodales',
#  'lorem',
#  'Aliquam',
#  'dapibus',
#  'faucibus',
#  'diam',
#  'Vestibulum',
#  'vel',
#  'magna',
#  'et',
#  'dolor',
#  'gravida',
#  'imperdiet',
#  'ut',
#  'sit',
#  'amet',
#  'sem',
#  'Lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet',
#  'consectetur',
#  'adipiscing',
#  'elit',
#  'Curabitur',
#  'elementum',
#  'metus',
#  'tincidunt',
#  'nulla',
#  'euismod',
#  'ultricies',
#  'Duis',
#  'elementum',
#  'nec',
#  'neque',
#  'in',
#  'porttitor',
#  'Nulla',
#  'sagittis',
#  'lorem',
#  'elit',
#  'et',
#  'consectetur',
#  'ante',
#  'laoreet',
#  'eu',
#  'Maecenas',
#  'nulla',
#  'tellus',
#  'scelerisque',
#  'ac',
#  'erat',
#  'sed',
#  'fermentum',
#  'dapibus',
#  'metus',
#  'Donec',
#  'tincidunt',
#  'fermentum',
#  'molestie',
#  "'",
#  "''",
#  "'Sed",
#  'consequat',
#  'mi',
#  'at',
#  'maximus',
#  'faucibus',
#  'Pellentesque',
#  'aliquet',
#  'tincidunt',
#  'sapien',
#  'vel',
#  ...]

# %%
word_count = list(map(lambda x: (x, 1), words))
word_count
# Out:
# Out[8]: [('', 1),
#  ("'Lorem", 1),
#  ('ipsum', 1),
#  ('dolor', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('consectetur', 1),
#  ('adipiscing', 1),
#  ('elit', 1),
#  ('Vivamus', 1),
#  ('condimentum', 1),
#  ('sagittis', 1),
#  ('lacus', 1),
#  ('laoreet', 1),
#  ('luctus', 1),
#  ('ligula', 1),
#  ('laoreet', 1),
#  ('ut', 1),
#  ('Vestibulum', 1),
#  ('ullamcorper', 1),
#  ('accumsan', 1),
#  ('velit', 1),
#  ('vel', 1),
#  ('vehicula', 1),
#  ('Proin', 1),
#  ('tempor', 1),
#  ('lacus', 1),
#  ('arcu', 1),
#  ('Nunc', 1),
#  ('at', 1),
#  ('elit', 1),
#  ('condimentum', 1),
#  ('semper', 1),
#  ('nisi', 1),
#  ('et', 1),
#  ('condimentum', 1),
#  ('mi', 1),
#  ('In', 1),
#  ('venenatis', 1),
#  ('blandit', 1),
#  ('nibh', 1),
#  ('at', 1),
#  ('sollicitudin', 1),
#  ('Vestibulum', 1),
#  ('dapibus', 1),
#  ('mauris', 1),
#  ('at', 1),
#  ('orci', 1),
#  ('maximus', 1),
#  ('pellentesque', 1),
#  ('Nullam', 1),
#  ('id', 1),
#  ('elementum', 1),
#  ('ipsum', 1),
#  ('Suspendisse', 1),
#  ('cursus', 1),
#  ('lobortis', 1),
#  ('viverra', 1),
#  ('Proin', 1),
#  ('et', 1),
#  ('erat', 1),
#  ('at', 1),
#  ('mauris', 1),
#  ('tincidunt', 1),
#  ('porttitor', 1),
#  ('vitae', 1),
#  ('ac', 1),
#  ('dui', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Donec", 1),
#  ('vulputate', 1),
#  ('lorem', 1),
#  ('tortor', 1),
#  ('nec', 1),
#  ('fermentum', 1),
#  ('nibh', 1),
#  ('bibendum', 1),
#  ('vel', 1),
#  ('Lorem', 1),
#  ('ipsum', 1),
#  ('dolor', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('consectetur', 1),
#  ('adipiscing', 1),
#  ('elit', 1),
#  ('Praesent', 1),
#  ('dictum', 1),
#  ('luctus', 1),
#  ('massa', 1),
#  ('non', 1),
#  ('euismod', 1),
#  ('lacus', 1),
#  ('Pellentesque', 1),
#  ('condimentum', 1),
#  ('dolor', 1),
#  ('est', 1),
#  ('ut', 1),
#  ('dapibus', 1),
#  ('lectus', 1),
#  ('luctus', 1),
#  ('ac', 1),
#  ('Ut', 1),
#  ('sagittis', 1),
#  ('commodo', 1),
#  ('arcu', 1),
#  ('Integer', 1),
#  ('nisi', 1),
#  ('nulla', 1),
#  ('facilisis', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('nulla', 1),
#  ('quis', 1),
#  ('eleifend', 1),
#  ('suscipit', 1),
#  ('purus', 1),
#  ('Class', 1),
#  ('aptent', 1),
#  ('taciti', 1),
#  ('sociosqu', 1),
#  ('ad', 1),
#  ('litora', 1),
#  ('torquent', 1),
#  ('per', 1),
#  ('conubia', 1),
#  ('nostra', 1),
#  ('per', 1),
#  ('inceptos', 1),
#  ('himenaeos', 1),
#  ('Aliquam', 1),
#  ('euismod', 1),
#  ('ultrices', 1),
#  ('lorem', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('imperdiet', 1),
#  ('est', 1),
#  ('tincidunt', 1),
#  ('vel', 1),
#  ('Phasellus', 1),
#  ('dictum', 1),
#  ('justo', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('ligula', 1),
#  ('varius', 1),
#  ('aliquet', 1),
#  ('auctor', 1),
#  ('et', 1),
#  ('metus', 1),
#  ('Fusce', 1),
#  ('vitae', 1),
#  ('tortor', 1),
#  ('et', 1),
#  ('nisi', 1),
#  ('pulvinar', 1),
#  ('vestibulum', 1),
#  ('eget', 1),
#  ('in', 1),
#  ('risus', 1),
#  ('Donec', 1),
#  ('ante', 1),
#  ('ex', 1),
#  ('placerat', 1),
#  ('a', 1),
#  ('lorem', 1),
#  ('eget', 1),
#  ('ultricies', 1),
#  ('bibendum', 1),
#  ('purus', 1),
#  ('Nam', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('neque', 1),
#  ('non', 1),
#  ('ante', 1),
#  ('laoreet', 1),
#  ('rutrum', 1),
#  ('Nullam', 1),
#  ('aliquet', 1),
#  ('commodo', 1),
#  ('urna', 1),
#  ('sed', 1),
#  ('ullamcorper', 1),
#  ('odio', 1),
#  ('feugiat', 1),
#  ('id', 1),
#  ('Mauris', 1),
#  ('nisi', 1),
#  ('sapien', 1),
#  ('porttitor', 1),
#  ('in', 1),
#  ('condimentum', 1),
#  ('nec', 1),
#  ('venenatis', 1),
#  ('eu', 1),
#  ('urna', 1),
#  ('Pellentesque', 1),
#  ('feugiat', 1),
#  ('diam', 1),
#  ('est', 1),
#  ('at', 1),
#  ('rhoncus', 1),
#  ('orci', 1),
#  ('porttitor', 1),
#  ('non', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Nulla", 1),
#  ('luctus', 1),
#  ('sem', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('nisi', 1),
#  ('consequat', 1),
#  ('id', 1),
#  ('ornare', 1),
#  ('ipsum', 1),
#  ('dignissim', 1),
#  ('Sed', 1),
#  ('elementum', 1),
#  ('elit', 1),
#  ('nibh', 1),
#  ('eu', 1),
#  ('condimentum', 1),
#  ('orci', 1),
#  ('viverra', 1),
#  ('quis', 1),
#  ('Aenean', 1),
#  ('suscipit', 1),
#  ('vitae', 1),
#  ('felis', 1),
#  ('non', 1),
#  ('suscipit', 1),
#  ('Suspendisse', 1),
#  ('pharetra', 1),
#  ('turpis', 1),
#  ('non', 1),
#  ('eros', 1),
#  ('semper', 1),
#  ('dictum', 1),
#  ('Etiam', 1),
#  ('tincidunt', 1),
#  ('venenatis', 1),
#  ('venenatis', 1),
#  ('Praesent', 1),
#  ('eget', 1),
#  ('gravida', 1),
#  ('lorem', 1),
#  ('ut', 1),
#  ('congue', 1),
#  ('diam', 1),
#  ('Etiam', 1),
#  ('facilisis', 1),
#  ('elit', 1),
#  ('at', 1),
#  ('porttitor', 1),
#  ('egestas', 1),
#  ('Praesent', 1),
#  ('consequat', 1),
#  ('velit', 1),
#  ('non', 1),
#  ('vulputate', 1),
#  ('convallis', 1),
#  ('ligula', 1),
#  ('diam', 1),
#  ('sagittis', 1),
#  ('urna', 1),
#  ('in', 1),
#  ('venenatis', 1),
#  ('nisi', 1),
#  ('justo', 1),
#  ('ut', 1),
#  ('mauris', 1),
#  ('Vestibulum', 1),
#  ('posuere', 1),
#  ('sollicitudin', 1),
#  ('mi', 1),
#  ('et', 1),
#  ('vulputate', 1),
#  ('nisl', 1),
#  ('fringilla', 1),
#  ('non', 1),
#  ('Nulla', 1),
#  ('ornare', 1),
#  ('pretium', 1),
#  ('velit', 1),
#  ('a', 1),
#  ('euismod', 1),
#  ('Nunc', 1),
#  ('sagittis', 1),
#  ('venenatis', 1),
#  ('vestibulum', 1),
#  ('Nunc', 1),
#  ('sodales', 1),
#  ('libero', 1),
#  ('a', 1),
#  ('est', 1),
#  ('ornare', 1),
#  ('ultricies', 1),
#  ('Sed', 1),
#  ('sed', 1),
#  ('leo', 1),
#  ('sed', 1),
#  ('orci', 1),
#  ('pellentesque', 1),
#  ('ultrices', 1),
#  ('Mauris', 1),
#  ('sollicitudin', 1),
#  ('sem', 1),
#  ('quis', 1),
#  ('placerat', 1),
#  ('ornare', 1),
#  ('velit', 1),
#  ('arcu', 1),
#  ('convallis', 1),
#  ('ligula', 1),
#  ('pretium', 1),
#  ('finibus', 1),
#  ('nisl', 1),
#  ('sapien', 1),
#  ('vel', 1),
#  ('sem', 1),
#  ('Vivamus', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('tortor', 1),
#  ('id', 1),
#  ('lorem', 1),
#  ('consequat', 1),
#  ('hendrerit', 1),
#  ('Nullam', 1),
#  ('at', 1),
#  ('dui', 1),
#  ('risus', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Vestibulum", 1),
#  ('ante', 1),
#  ('ipsum', 1),
#  ('primis', 1),
#  ('in', 1),
#  ('faucibus', 1),
#  ('orci', 1),
#  ('luctus', 1),
#  ('et', 1),
#  ('ultrices', 1),
#  ('posuere', 1),
#  ('cubilia', 1),
#  ('Curae;', 1),
#  ('Lorem', 1),
#  ('ipsum', 1),
#  ('dolor', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('consectetur', 1),
#  ('adipiscing', 1),
#  ('elit', 1),
#  ('Sed', 1),
#  ('feugiat', 1),
#  ('semper', 1),
#  ('velit', 1),
#  ('consequat', 1),
#  ('facilisis', 1),
#  ('Etiam', 1),
#  ('facilisis', 1),
#  ('justo', 1),
#  ('non', 1),
#  ('iaculis', 1),
#  ('dictum', 1),
#  ('Fusce', 1),
#  ('turpis', 1),
#  ('neque', 1),
#  ('pharetra', 1),
#  ('ut', 1),
#  ('odio', 1),
#  ('eu', 1),
#  ('hendrerit', 1),
#  ('rhoncus', 1),
#  ('lacus', 1),
#  ('Nunc', 1),
#  ('orci', 1),
#  ('felis', 1),
#  ('imperdiet', 1),
#  ('vel', 1),
#  ('interdum', 1),
#  ('quis', 1),
#  ('porta', 1),
#  ('eu', 1),
#  ('ipsum', 1),
#  ('Pellentesque', 1),
#  ('dictum', 1),
#  ('sem', 1),
#  ('lacinia', 1),
#  ('auctor', 1),
#  ('dui', 1),
#  ('in', 1),
#  ('malesuada', 1),
#  ('nunc', 1),
#  ('Maecenas', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('mollis', 1),
#  ('eros', 1),
#  ('Proin', 1),
#  ('fringilla', 1),
#  ('viverra', 1),
#  ('ligula', 1),
#  ('sollicitudin', 1),
#  ('viverra', 1),
#  ('ante', 1),
#  ('sollicitudin', 1),
#  ('congue', 1),
#  ('Donec', 1),
#  ('mollis', 1),
#  ('felis', 1),
#  ('eu', 1),
#  ('libero', 1),
#  ('malesuada', 1),
#  ('et', 1),
#  ('lacinia', 1),
#  ('risus', 1),
#  ('interdum', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Etiam", 1),
#  ('vitae', 1),
#  ('accumsan', 1),
#  ('augue', 1),
#  ('Ut', 1),
#  ('urna', 1),
#  ('orci', 1),
#  ('malesuada', 1),
#  ('ut', 1),
#  ('nisi', 1),
#  ('a', 1),
#  ('condimentum', 1),
#  ('gravida', 1),
#  ('magna', 1),
#  ('Nulla', 1),
#  ('bibendum', 1),
#  ('ex', 1),
#  ('in', 1),
#  ('vulputate', 1),
#  ('sagittis', 1),
#  ('Nulla', 1),
#  ('facilisi', 1),
#  ('Nullam', 1),
#  ('faucibus', 1),
#  ('et', 1),
#  ('metus', 1),
#  ('ac', 1),
#  ('consequat', 1),
#  ('Quisque', 1),
#  ('tempor', 1),
#  ('eros', 1),
#  ('velit', 1),
#  ('id', 1),
#  ('mattis', 1),
#  ('nibh', 1),
#  ('aliquet', 1),
#  ('a', 1),
#  ('Aenean', 1),
#  ('tempor', 1),
#  ('elit', 1),
#  ('ut', 1),
#  ('finibus', 1),
#  ('auctor', 1),
#  ('Sed', 1),
#  ('at', 1),
#  ('imperdiet', 1),
#  ('mauris', 1),
#  ('Vestibulum', 1),
#  ('pharetra', 1),
#  ('non', 1),
#  ('lacus', 1),
#  ('sed', 1),
#  ('pulvinar', 1),
#  ('Sed', 1),
#  ('pellentesque', 1),
#  ('magna', 1),
#  ('a', 1),
#  ('eros', 1),
#  ('volutpat', 1),
#  ('ullamcorper', 1),
#  ('In', 1),
#  ('hac', 1),
#  ('habitasse', 1),
#  ('platea', 1),
#  ('dictumst', 1),
#  ('Donec', 1),
#  ('ipsum', 1),
#  ('mi', 1),
#  ('feugiat', 1),
#  ('in', 1),
#  ('eros', 1),
#  ('sed', 1),
#  ('varius', 1),
#  ('lacinia', 1),
#  ('turpis', 1),
#  ('Donec', 1),
#  ('vulputate', 1),
#  ('tincidunt', 1),
#  ('dui', 1),
#  ('ac', 1),
#  ('laoreet', 1),
#  ('Sed', 1),
#  ('in', 1),
#  ('eros', 1),
#  ('dui', 1),
#  ('Pellentesque', 1),
#  ('placerat', 1),
#  ('tristique', 1),
#  ('ligula', 1),
#  ('eu', 1),
#  ('finibus', 1),
#  ('Proin', 1),
#  ('nec', 1),
#  ('faucibus', 1),
#  ('felis', 1),
#  ('eu', 1),
#  ('commodo', 1),
#  ('ipsum', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Integer", 1),
#  ('eu', 1),
#  ('hendrerit', 1),
#  ('diam', 1),
#  ('sed', 1),
#  ('consectetur', 1),
#  ('nunc', 1),
#  ('Aliquam', 1),
#  ('a', 1),
#  ('sem', 1),
#  ('vitae', 1),
#  ('leo', 1),
#  ('fermentum', 1),
#  ('faucibus', 1),
#  ('quis', 1),
#  ('at', 1),
#  ('sem', 1),
#  ('Etiam', 1),
#  ('blandit', 1),
#  ('quam', 1),
#  ('quis', 1),
#  ('fermentum', 1),
#  ('varius', 1),
#  ('ante', 1),
#  ('urna', 1),
#  ('ultricies', 1),
#  ('lectus', 1),
#  ('vel', 1),
#  ('pellentesque', 1),
#  ('ligula', 1),
#  ('arcu', 1),
#  ('nec', 1),
#  ('elit', 1),
#  ('Donec', 1),
#  ('placerat', 1),
#  ('ante', 1),
#  ('in', 1),
#  ('enim', 1),
#  ('scelerisque', 1),
#  ('pretium', 1),
#  ('Donec', 1),
#  ('et', 1),
#  ('rhoncus', 1),
#  ('erat', 1),
#  ('Aenean', 1),
#  ('tempor', 1),
#  ('nisi', 1),
#  ('vitae', 1),
#  ('augue', 1),
#  ('tincidunt', 1),
#  ('luctus', 1),
#  ('Nam', 1),
#  ('condimentum', 1),
#  ('dictum', 1),
#  ('ante', 1),
#  ('et', 1),
#  ('laoreet', 1),
#  ('neque', 1),
#  ('pellentesque', 1),
#  ('id', 1),
#  ('Curabitur', 1),
#  ('consectetur', 1),
#  ('cursus', 1),
#  ('neque', 1),
#  ('aliquam', 1),
#  ('porta', 1),
#  ('Ut', 1),
#  ('interdum', 1),
#  ('nunc', 1),
#  ('nec', 1),
#  ('nibh', 1),
#  ('vestibulum', 1),
#  ('in', 1),
#  ('sagittis', 1),
#  ('metus', 1),
#  ('facilisis', 1),
#  ('Pellentesque', 1),
#  ('feugiat', 1),
#  ('condimentum', 1),
#  ('metus', 1),
#  ('Etiam', 1),
#  ('venenatis', 1),
#  ('quam', 1),
#  ('at', 1),
#  ('ante', 1),
#  ('rhoncus', 1),
#  ('vestibulum', 1),
#  ('Maecenas', 1),
#  ('suscipit', 1),
#  ('congue', 1),
#  ('pellentesque', 1),
#  ('Vestibulum', 1),
#  ('suscipit', 1),
#  ('scelerisque', 1),
#  ('fermentum', 1),
#  ('Nulla', 1),
#  ('iaculis', 1),
#  ('risus', 1),
#  ('ac', 1),
#  ('vulputate', 1),
#  ('porttitor', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Mauris", 1),
#  ('nec', 1),
#  ('metus', 1),
#  ('vel', 1),
#  ('dolor', 1),
#  ('blandit', 1),
#  ('faucibus', 1),
#  ('et', 1),
#  ('vel', 1),
#  ('magna', 1),
#  ('Ut', 1),
#  ('tincidunt', 1),
#  ('ipsum', 1),
#  ('non', 1),
#  ('nunc', 1),
#  ('dapibus', 1),
#  ('sed', 1),
#  ('blandit', 1),
#  ('mi', 1),
#  ('condimentum', 1),
#  ('Quisque', 1),
#  ('pharetra', 1),
#  ('interdum', 1),
#  ('quam', 1),
#  ('nec', 1),
#  ('feugiat', 1),
#  ('Sed', 1),
#  ('pellentesque', 1),
#  ('nulla', 1),
#  ('et', 1),
#  ('turpis', 1),
#  ('blandit', 1),
#  ('interdum', 1),
#  ('Curabitur', 1),
#  ('at', 1),
#  ('metus', 1),
#  ('vitae', 1),
#  ('augue', 1),
#  ('elementum', 1),
#  ('viverra', 1),
#  ('Sed', 1),
#  ('mattis', 1),
#  ('lorem', 1),
#  ('non', 1),
#  ('enim', 1),
#  ('fermentum', 1),
#  ('finibus', 1),
#  ('Sed', 1),
#  ('at', 1),
#  ('dui', 1),
#  ('in', 1),
#  ('magna', 1),
#  ('dignissim', 1),
#  ('accumsan', 1),
#  ('Proin', 1),
#  ('tincidunt', 1),
#  ('ultricies', 1),
#  ('cursus', 1),
#  ('Maecenas', 1),
#  ('tincidunt', 1),
#  ('magna', 1),
#  ('at', 1),
#  ('urna', 1),
#  ('faucibus', 1),
#  ('lacinia', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Quisque", 1),
#  ('venenatis', 1),
#  ('justo', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('tortor', 1),
#  ('condimentum', 1),
#  ('nec', 1),
#  ('tincidunt', 1),
#  ('tellus', 1),
#  ('viverra', 1),
#  ('Morbi', 1),
#  ('risus', 1),
#  ('ipsum', 1),
#  ('consequat', 1),
#  ('convallis', 1),
#  ('malesuada', 1),
#  ('non', 1),
#  ('fermentum', 1),
#  ('non', 1),
#  ('velit', 1),
#  ('Nulla', 1),
#  ('facilisis', 1),
#  ('orci', 1),
#  ('eget', 1),
#  ('ligula', 1),
#  ('mattis', 1),
#  ('fermentum', 1),
#  ('Aliquam', 1),
#  ('vel', 1),
#  ('velit', 1),
#  ('ultricies', 1),
#  ('sollicitudin', 1),
#  ('nibh', 1),
#  ('eu', 1),
#  ('congue', 1),
#  ('velit', 1),
#  ('Donec', 1),
#  ('nulla', 1),
#  ('lorem', 1),
#  ('euismod', 1),
#  ('id', 1),
#  ('cursus', 1),
#  ('at', 1),
#  ('sollicitudin', 1),
#  ('et', 1),
#  ('arcu', 1),
#  ('Proin', 1),
#  ('vitae', 1),
#  ('tincidunt', 1),
#  ('ipsum', 1),
#  ('Vivamus', 1),
#  ('elementum', 1),
#  ('eleifend', 1),
#  ('justo', 1),
#  ('placerat', 1),
#  ('interdum', 1),
#  ('nulla', 1),
#  ('rutrum', 1),
#  ('id', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Phasellus", 1),
#  ('fringilla', 1),
#  ('luctus', 1),
#  ('magna', 1),
#  ('a', 1),
#  ('finibus', 1),
#  ('justo', 1),
#  ('dapibus', 1),
#  ('a', 1),
#  ('Nam', 1),
#  ('risus', 1),
#  ('felis', 1),
#  ('rhoncus', 1),
#  ('eget', 1),
#  ('diam', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('congue', 1),
#  ('facilisis', 1),
#  ('nibh', 1),
#  ('Interdum', 1),
#  ('et', 1),
#  ('malesuada', 1),
#  ('fames', 1),
#  ('ac', 1),
#  ('ante', 1),
#  ('ipsum', 1),
#  ('primis', 1),
#  ('in', 1),
#  ('faucibus', 1),
#  ('Praesent', 1),
#  ('consequat', 1),
#  ('euismod', 1),
#  ('diam', 1),
#  ('eget', 1),
#  ('volutpat', 1),
#  ('magna', 1),
#  ('convallis', 1),
#  ('at', 1),
#  ('Mauris', 1),
#  ('placerat', 1),
#  ('pellentesque', 1),
#  ('imperdiet', 1),
#  ('Nulla', 1),
#  ('porta', 1),
#  ('scelerisque', 1),
#  ('enim', 1),
#  ('et', 1),
#  ('scelerisque', 1),
#  ('neque', 1),
#  ('bibendum', 1),
#  ('in', 1),
#  ('Proin', 1),
#  ('eget', 1),
#  ('turpis', 1),
#  ('nisi', 1),
#  ('Suspendisse', 1),
#  ('ut', 1),
#  ('est', 1),
#  ('a', 1),
#  ('erat', 1),
#  ('egestas', 1),
#  ('eleifend', 1),
#  ('at', 1),
#  ('euismod', 1),
#  ('arcu', 1),
#  ('Donec', 1),
#  ('aliquet', 1),
#  ('nisi', 1),
#  ('sed', 1),
#  ('faucibus', 1),
#  ('condimentum', 1),
#  ('nisi', 1),
#  ('metus', 1),
#  ('dictum', 1),
#  ('eros', 1),
#  ('nec', 1),
#  ('dignissim', 1),
#  ('justo', 1),
#  ('odio', 1),
#  ('id', 1),
#  ('nulla', 1),
#  ('Pellentesque', 1),
#  ('habitant', 1),
#  ('morbi', 1),
#  ('tristique', 1),
#  ('senectus', 1),
#  ('et', 1),
#  ('netus', 1),
#  ('et', 1),
#  ('malesuada', 1),
#  ('fames', 1),
#  ('ac', 1),
#  ('turpis', 1),
#  ('egestas', 1),
#  ('Maecenas', 1),
#  ('sollicitudin', 1),
#  ('justo', 1),
#  ('id', 1),
#  ('elementum', 1),
#  ('eleifend', 1),
#  ('justo', 1),
#  ('neque', 1),
#  ('aliquet', 1),
#  ('nibh', 1),
#  ('finibus', 1),
#  ('malesuada', 1),
#  ('metus', 1),
#  ('erat', 1),
#  ('eget', 1),
#  ('neque', 1),
#  ('Suspendisse', 1),
#  ('nec', 1),
#  ('auctor', 1),
#  ('orci', 1),
#  ('Aenean', 1),
#  ('et', 1),
#  ('vestibulum', 1),
#  ('nulla', 1),
#  ('Nullam', 1),
#  ('hendrerit', 1),
#  ('augue', 1),
#  ('tristique', 1),
#  ('commodo', 1),
#  ('metus', 1),
#  ('id', 1),
#  ('sodales', 1),
#  ('lorem', 1),
#  ('Etiam', 1),
#  ('feugiat', 1),
#  ('dui', 1),
#  ('est', 1),
#  ('vitae', 1),
#  ('auctor', 1),
#  ('risus', 1),
#  ('convallis', 1),
#  ('non', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Maecenas", 1),
#  ('turpis', 1),
#  ('enim', 1),
#  ('consectetur', 1),
#  ('eget', 1),
#  ('lectus', 1),
#  ('eu', 1),
#  ('hendrerit', 1),
#  ('posuere', 1),
#  ('lacus', 1),
#  ('Praesent', 1),
#  ('efficitur', 1),
#  ('felis', 1),
#  ('eget', 1),
#  ('dapibus', 1),
#  ('consectetur', 1),
#  ('nisi', 1),
#  ('massa', 1),
#  ('dignissim', 1),
#  ('enim', 1),
#  ('nec', 1),
#  ('semper', 1),
#  ('dolor', 1),
#  ('est', 1),
#  ('eu', 1),
#  ('urna', 1),
#  ('Nullam', 1),
#  ('ut', 1),
#  ('sodales', 1),
#  ('lorem', 1),
#  ('Aliquam', 1),
#  ('dapibus', 1),
#  ('faucibus', 1),
#  ('diam', 1),
#  ('Vestibulum', 1),
#  ('vel', 1),
#  ('magna', 1),
#  ('et', 1),
#  ('dolor', 1),
#  ('gravida', 1),
#  ('imperdiet', 1),
#  ('ut', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('sem', 1),
#  ('Lorem', 1),
#  ('ipsum', 1),
#  ('dolor', 1),
#  ('sit', 1),
#  ('amet', 1),
#  ('consectetur', 1),
#  ('adipiscing', 1),
#  ('elit', 1),
#  ('Curabitur', 1),
#  ('elementum', 1),
#  ('metus', 1),
#  ('tincidunt', 1),
#  ('nulla', 1),
#  ('euismod', 1),
#  ('ultricies', 1),
#  ('Duis', 1),
#  ('elementum', 1),
#  ('nec', 1),
#  ('neque', 1),
#  ('in', 1),
#  ('porttitor', 1),
#  ('Nulla', 1),
#  ('sagittis', 1),
#  ('lorem', 1),
#  ('elit', 1),
#  ('et', 1),
#  ('consectetur', 1),
#  ('ante', 1),
#  ('laoreet', 1),
#  ('eu', 1),
#  ('Maecenas', 1),
#  ('nulla', 1),
#  ('tellus', 1),
#  ('scelerisque', 1),
#  ('ac', 1),
#  ('erat', 1),
#  ('sed', 1),
#  ('fermentum', 1),
#  ('dapibus', 1),
#  ('metus', 1),
#  ('Donec', 1),
#  ('tincidunt', 1),
#  ('fermentum', 1),
#  ('molestie', 1),
#  ("'", 1),
#  ("''", 1),
#  ("'Sed", 1),
#  ('consequat', 1),
#  ('mi', 1),
#  ('at', 1),
#  ('maximus', 1),
#  ('faucibus', 1),
#  ('Pellentesque', 1),
#  ('aliquet', 1),
#  ('tincidunt', 1),
#  ('sapien', 1),
#  ('vel', 1),
#  ...]

# %%
word_counts = {}
for word in words:
    word = word.lower()
    word_counts[word] = word_counts.get(word, 0) + 1

print(f'Total number of words:  {sum(word_counts.values())} \n\nList of Words:  \n\n{word_counts.items()} ')
# Out:
# Total number of words:  7557
#
# List of Words:
#
# dict_items([('', 2), ("'lorem", 2), ('ipsum', 63), ('dolor', 46), ('sit', 99), ('amet', 99), ('consectetur', 36), ('adipiscing', 8), ('elit', 58), ('vivamus', 30), ('condimentum', 32), ('sagittis', 42), ('lacus', 43), ('laoreet', 32), ('luctus', 38), ('ligula', 50), ('ut', 112), ('vestibulum', 78), ('ullamcorper', 30), ('accumsan', 34), ('velit', 42), ('vel', 83), ('vehicula', 38), ('proin', 31), ('tempor', 42), ('arcu', 34), ('nunc', 79), ('at', 93), ('semper', 27), ('nisi', 53), ('et', 136), ('mi', 48), ('in', 128), ('venenatis', 43), ('blandit', 36), ('nibh', 51), ('sollicitudin', 27), ('dapibus', 36), ('mauris', 77), ('orci', 48), ('maximus', 33), ('pellentesque', 83), ('nullam', 30), ('id', 83), ('elementum', 32), ('suspendisse', 36), ('cursus', 31), ('lobortis', 40), ('viverra', 33), ('erat', 43), ('tincidunt', 57), ('porttitor', 37), ('vitae', 96), ('ac', 90), ('dui', 62), ("'", 80), ("''", 80), ("'donec", 5), ('vulputate', 42), ('lorem', 52), ('tortor', 41), ('nec', 86), ('fermentum', 38), ('bibendum', 24), ('praesent', 32), ('dictum', 45), ('massa', 42), ('non', 91), ('euismod', 35), ('est', 44), ('lectus', 47), ('commodo', 39), ('integer', 29), ('nulla', 86), ('facilisis', 42), ('quis', 97), ('eleifend', 40), ('suscipit', 30), ('purus', 36), ('class', 5), ('aptent', 6), ('taciti', 6), ('sociosqu', 6), ('ad', 6), ('litora', 6), ('torquent', 6), ('per', 12), ('conubia', 6), ('nostra', 6), ('inceptos', 6), ('himenaeos', 6), ('aliquam', 57), ('ultrices', 28), ('imperdiet', 36), ('phasellus', 28), ('justo', 40), ('varius', 35), ('aliquet', 54), ('auctor', 33), ('metus', 48), ('fusce', 23), ('pulvinar', 22), ('eget', 80), ('risus', 54), ('donec', 51), ('ante', 55), ('ex', 42), ('placerat', 33), ('a', 95), ('ultricies', 38), ('nam', 32), ('neque', 43), ('rutrum', 32), ('urna', 44), ('sed', 153), ('odio', 36), ('feugiat', 23), ('sapien', 37), ('eu', 91), ('diam', 42), ('rhoncus', 31), ("'nulla", 4), ('sem', 54), ('consequat', 35), ('ornare', 32), ('dignissim', 41), ('aenean', 29), ('felis', 45), ('pharetra', 42), ('turpis', 62), ('eros', 49), ('etiam', 27), ('gravida', 39), ('congue', 38), ('egestas', 46), ('convallis', 37), ('posuere', 38), ('nisl', 39), ('fringilla', 32), ('pretium', 31), ('sodales', 27), ('libero', 47), ('leo', 40), ('finibus', 35), ('hendrerit', 34), ("'vestibulum", 3), ('primis', 11), ('faucibus', 59), ('cubilia', 5), ('curae;', 4), ('iaculis', 29), ('interdum', 39), ('porta', 28), ('lacinia', 27), ('malesuada', 49), ('maecenas', 20), ('mollis', 31), ("'etiam", 2), ('augue', 51), ('magna', 41), ('facilisi', 8), ('quisque', 19), ('mattis', 30), ('volutpat', 37), ('hac', 2), ('habitasse', 2), ('platea', 2), ('dictumst', 2), ('tristique', 45), ("'integer", 3), ('quam', 51), ('enim', 53), ('scelerisque', 34), ('curabitur', 31), ("'mauris", 2), ("'quisque", 1), ('tellus', 57), ('morbi', 32), ("'phasellus", 6), ('fames', 15), ('habitant', 9), ('senectus', 9), ('netus', 9), ("'maecenas", 5), ('efficitur', 33), ('duis', 23), ('molestie', 30), ("'sed", 8), ('potenti', 5), ("'suspendisse", 5), ("curae;'", 1), ("'curabitur", 7), ('cras', 34), ('tempus', 25), ("'in", 3), ('cum', 4), ('sociis', 4), ('natoque', 4), ('penatibus', 4), ('magnis', 4), ('dis', 4), ('parturient', 4), ('montes', 4), ('nascetur', 4), ('ridiculus', 4), ('mus', 4), ("'vivamus", 2), ("'aliquam", 2), ("'pellentesque", 6), ("'praesent", 3), ("'class", 1), ("'fusce", 4), ("'nam", 1), ("'nunc", 1), ("'interdum", 1), ("'cras", 1), ("'duis", 3)])
