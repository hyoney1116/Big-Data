# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      |▍
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#      |████████████████████████████████| 317.0 MB 10 kB/s
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 34.0 MB/s
# Building wheels for collected packages: pyspark
# done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488511 sha256=459c051bbc1946b441850b4c58b5440f77e8ac84e7c17923db40299db2af9070
#   Stored in directory: /root/.cache/pip/wheels/92/09/11/aa01d01a7f005fda8a66ad71d2be7f8aa341bddafb27eee3c7
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.7 pyspark-3.5.1
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-908aec72-c1c7-436c-be30-255584da6258/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# – TASK-1: Generate 100 random numbers in range 0 to 10 using numpy randint function with the seed set to 10. Create a RDD using the parallelize function using data generated in previous step. Calculate the frequency of each number (0 - 10) using appropriate function of RDD.

# %%
import numpy as np
from pyspark import SparkContext

# %%
# Generate 100 random numbers using numpy
np.random.seed(10)
data = np.random.randint(0, 11, 100)

data
# Out:
# Out[3]: array([ 9,  4,  0,  1,  9,  0,  1, 10,  8,  9,  0, 10,  8,  6,  4,  3,  0,
#         4,  6,  8, 10,  1,  8,  4,  1,  3,  6,  5,  3,  9,  6,  9,  1,  9,
#         4,  2,  6,  7,  8, 10,  8,  9,  2,  0,  6,  7,  8,  1,  7,  1,  4,
#        10,  0,  8,  5,  4,  7,  8,  8,  2,  6,  2,  8,  8,  6,  6,  5, 10,
#         6,  0,  0,  6,  9,  1,  8, 10,  9,  1,  2,  8,  9,  9,  5,  0,  2,
#         7,  3,  0,  4,  2,  0,  3,  3,  1,  2,  5,  9,  0, 10,  1])

# %%
rdd = sc.parallelize(data)

frequency = rdd.map(lambda x: (x, 1)).countByKey()
for num, freq in sorted(frequency.items()):
    print(f"Number {num}: Frequency {freq}")
# Out:
# Number 0: Frequency 12
# Number 1: Frequency 11
# Number 2: Frequency 8
# Number 3: Frequency 6
# Number 4: Frequency 8
# Number 5: Frequency 5
# Number 6: Frequency 11
# Number 7: Frequency 5
# Number 8: Frequency 14
# Number 9: Frequency 12
# Number 10: Frequency 8

# %% [markdown]
# – TASK-2: In this task you will calculate the frequency of each word in text8 dataset mentioned above. Create a RDD using the text8 dataset. Use appropriate functions of the RDD to get the word frequencies. Filter the RDD using appropriate function to get the frequencies of words containing the letter ’a’.

# %%
text8 = sc.textFile("dbfs:/FileStore/shared_uploads/202318044@daiict.ac.in/text8")

# Split each line into words and flatten the list of words
words = text8.flatMap(lambda line: line.split())
word_count = words.map(lambda word: (word, 1))

# Reduce by key to get word frequencies
word_frequencies = word_count.reduceByKey(lambda x, y: x + y)

# Filter out words containing the letter 'a'
words_a = word_frequencies.filter(lambda pair: 'a' in pair[0])

word_frequencies_with_a = words_a.collect()
for word, frequency in word_frequencies_with_a:
    print(f"Word: {word}, Frequency: {frequency}")
# Out:
# Word: against, Frequency: 8432
# Word: an, Frequency: 61925
# Word: anarchiste, Frequency: 2
# Word: take, Frequency: 4105
# Word: hakim, Frequency: 27
# Word: relating, Frequency: 353
# Word: diagnostic, Frequency: 132
# Word: passed, Frequency: 1600
# Word: conversation, Frequency: 241
# Word: preparing, Frequency: 183
# Word: accounted, Frequency: 139
# Word: vague, Frequency: 123
# Word: statement, Frequency: 1134
# Word: handicapped, Frequency: 40
# Word: multigenerational, Frequency: 2
# Word: averages, Frequency: 125
# Word: suburban, Frequency: 167
# Word: naye, Frequency: 1
# Word: akhos, Frequency: 1
# Word: beggar, Frequency: 24
# Word: daughters, Frequency: 319
# Word: militia, Frequency: 263
# Word: operate, Frequency: 571
# Word: stained, Frequency: 72
# Word: humanists, Frequency: 65
# Word: presocratic, Frequency: 22
# Word: anatomy, Frequency: 284
# Word: adviser, Frequency: 59
# Word: hearted, Frequency: 59
# Word: passion, Frequency: 241
# Word: divinatione, Frequency: 2
# Word: cinema, Frequency: 660
# Word: barriers, Frequency: 153
# Word: coaching, Frequency: 87
# Word: vanderbilt, Frequency: 33
# Word: brane, Frequency: 20
# Word: boulevard, Frequency: 110
# Word: oats, Frequency: 32
# Word: algerian, Frequency: 96
# Word: reached, Frequency: 1467
# Word: numidian, Frequency: 5
# Word: harkis, Frequency: 3
# Word: dahmane, Frequency: 1
# Word: algerie, Frequency: 3
# Word: alloy, Frequency: 131
# Word: retreated, Frequency: 114
# Word: camouflage, Frequency: 134
# Word: allegorical, Frequency: 73
# Word: anthropology, Frequency: 379
# Word: treasures, Frequency: 99
# Word: sagar, Frequency: 4
# Word: platonic, Frequency: 92
# Word: balances, Frequency: 57
# Word: paracelsian, Frequency: 1
# Word: vitamins, Frequency: 51
# Word: forbade, Frequency: 73
# Word: penal, Frequency: 112
# Word: administers, Frequency: 29
# Word: mcdonald, Frequency: 114
# Word: arafura, Frequency: 6
# Word: vocational, Frequency: 72
# Word: fairfax, Frequency: 49
# Word: atua, Frequency: 3
# Word: matu, Frequency: 1
# Word: formats, Frequency: 398
# Word: protozoa, Frequency: 35
# Word: assignments, Frequency: 68
# Word: isolated, Frequency: 511
# Word: disembarkations, Frequency: 2
# Word: korda, Frequency: 6
# Word: manufactured, Frequency: 432
# Word: favoring, Frequency: 53
# Word: adopting, Frequency: 134
# Word: lambasting, Frequency: 2
# Word: chartered, Frequency: 106
# Word: authorizes, Frequency: 20
# Word: breastfeeding, Frequency: 15
# Word: bonaparte, Frequency: 159
# Word: cuba, Frequency: 745
# Word: hatching, Frequency: 19
# Word: framed, Frequency: 73
# Word: squares, Frequency: 204
# Word: predominating, Frequency: 7
# Word: catalytic, Frequency: 67
# Word: attempte, Frequency: 1
# Word: magnifier, Frequency: 2
# Word: stadium, Frequency: 792
# Word: diplomas, Frequency: 19
# Word: quarters, Frequency: 206
# Word: wan, Frequency: 72
# Word: syllabics, Frequency: 13
# Word: aardwolf, Frequency: 11
# Word: asperrima, Frequency: 1
# Word: parrasana, Frequency: 1
# Word: determination, Frequency: 257
# Word: walton, Frequency: 50
# Word: walvis, Frequency: 6
# Word: commensurate, Frequency: 12
# Word: caconda, Frequency: 1
# Word: protracted, Frequency: 56
# Word: crabs, Frequency: 27
# Word: platyhelminthes, Frequency: 2
# Word: jaguar, Frequency: 155
# Word: peacock, Frequency: 46
# Word: sawfish, Frequency: 2
# Word: osteoglossomorpha, Frequency: 1
# Word: protacanthopterygii, Frequency: 1
# Word: plait, Frequency: 7
# Word: arrian, Frequency: 20
# Word: saddozay, Frequency: 1
# Word: warlords, Frequency: 42
# Word: nasher, Frequency: 5
# Word: khalili, Frequency: 2
# Word: uncomplicated, Frequency: 10
# Word: craftsmen, Frequency: 47
# Word: faltered, Frequency: 10
# Word: painful, Frequency: 135
# Word: aikid, Frequency: 1
# Word: centralized, Frequency: 144
# Word: relays, Frequency: 48
# Word: crossbar, Frequency: 20
# Word: programmer, Frequency: 247
# Word: hesitated, Frequency: 13
# Word: susa, Frequency: 19
# Word: dora, Frequency: 47
# Word: alexandrists, Frequency: 5
# Word: valerio, Frequency: 3
# Word: anitkabir, Frequency: 1
# Word: novella, Frequency: 99
# Word: sharky, Frequency: 2
# Word: fashionable, Frequency: 69
# Word: blanche, Frequency: 41
# Word: artfully, Frequency: 7
# Word: malaya, Frequency: 97
# Word: arancia, Frequency: 1
# Word: heldhaftig, Frequency: 1
# Word: jaap, Frequency: 8
# Word: unassisted, Frequency: 3
# Word: pedal, Frequency: 83
# Word: ramjet, Frequency: 18
# Word: paf, Frequency: 2
# Word: rdaibh, Frequency: 1
# Word: luwians, Frequency: 1
# Word: mutersaflik, Frequency: 3
# Word: konya, Frequency: 18
# Word: hallmark, Frequency: 46
# Word: macintouch, Frequency: 1
# Word: realignment, Frequency: 24
# Word: roadmap, Frequency: 21
# Word: naomi, Frequency: 33
# Word: formularizations, Frequency: 1
# Word: intestinal, Frequency: 60
# Word: bookmarked, Frequency: 1
# Word: yevna, Frequency: 1
# Word: probabilities, Frequency: 80
# Word: chromated, Frequency: 1
# Word: covalent, Frequency: 122
# Word: machined, Frequency: 19
# Word: acetylide, Frequency: 5
# Word: aldabra, Frequency: 3
# Word: vineyard, Frequency: 23
# Word: depressants, Frequency: 13
# Word: incriminating, Frequency: 19
# Word: miersia, Frequency: 1
# Word: actuelles, Frequency: 1
# Word: granada, Frequency: 95
# Word: gonzalas, Frequency: 1
# Word: zamfir, Frequency: 5
# Word: alessandro, Frequency: 62
# Word: breasted, Frequency: 12
# Word: tosylate, Frequency: 1
# Word: harlay, Frequency: 2
# Word: kramnik, Frequency: 18
# Word: karts, Frequency: 12
# Word: appropriates, Frequency: 4
# Word: reynaldo, Frequency: 2
# Word: lemnian, Frequency: 8
# Word: lapels, Frequency: 3
# Word: pictographs, Frequency: 4
# Word: aalborgt, Frequency: 1
# Word: aroma, Frequency: 61
# Word: aziz, Frequency: 43
# Word: anges, Frequency: 3
# Word: crainquebille, Frequency: 1
# Word: pastorale, Frequency: 3
# Word: esadlo, Frequency: 2
# Word: apothecary, Frequency: 7
# Word: bookmaker, Frequency: 5
# Word: acheul, Frequency: 1
# Word: diaconate, Frequency: 10
# Word: canine, Frequency: 44
# Word: multiplications, Frequency: 33
# Word: pysharmonika, Frequency: 1
# Word: ware, Frequency: 50
# Word: ishtar, Frequency: 40
# Word: abas, Frequency: 3
# Word: voyaging, Frequency: 10
# Word: averted, Frequency: 20
# Word: determinants, Frequency: 49
# Word: masatake, Frequency: 3
# Word: chakravarti, Frequency: 4
# Word: nacirema, Frequency: 1
# Word: suda, Frequency: 12
# Word: objectada, Frequency: 1
# Word: caciques, Frequency: 3
# Word: mambres, Frequency: 1
# Word: alexandrians, Frequency: 9
# Word: subcostal, Frequency: 4
# Word: debilitated, Frequency: 5
# Word: oblati, Frequency: 1
# Word: petajoules, Frequency: 2
# Word: mansart, Frequency: 4
# Word: commutativity, Frequency: 27
# Word: alternativity, Frequency: 3
# Word: nahr, Frequency: 8
# Word: amorum, Frequency: 1
# Word: thiocyanate, Frequency: 3
# Word: taxa, Frequency: 40
# Word: secundianus, Frequency: 2
# Word: threateded, Frequency: 1
# Word: macromolecule, Frequency: 12
# Word: impregnation, Frequency: 2
# Word: industrially, Frequency: 27
# Word: vases, Frequency: 35
# Word: matsir, Frequency: 1
# Word: caputalgol, Frequency: 1
# Word: karaji, Frequency: 4
# Word: dialog, Frequency: 67
# Word: aqeous, Frequency: 1
# Word: cavafy, Frequency: 3
# Word: laporte, Frequency: 5
# Word: chedorlaomer, Frequency: 2
# Word: garstang, Frequency: 4
# Word: vardzia, Frequency: 1
# Word: carracci, Frequency: 12
# Word: mateja, Frequency: 1
# Word: alani, Frequency: 1
# Word: alamannia, Frequency: 5
# Word: nationalisation, Frequency: 19
# Word: killa, Frequency: 4
# Word: pawe, Frequency: 7
# Word: zeray, Frequency: 2
# Word: aksyonov, Frequency: 1
# Word: lutheranism, Frequency: 40
# Word: equitation, Frequency: 5
# Word: walheim, Frequency: 3
# Word: sneader, Frequency: 1
# Word: arterial, Frequency: 33
# Word: sunazawa, Frequency: 1
# Word: uan, Frequency: 12
# Word: ismailism, Frequency: 1
# Word: albano, Frequency: 6
# Word: soares, Frequency: 15
# Word: upstart, Frequency: 14
# Word: walberer, Frequency: 1
# Word: epigrammatum, Frequency: 1
# Word: alapaevsk, Frequency: 1
# Word: slavophile, Frequency: 2
# Word: alasdair, Frequency: 5
# Word: piacenza, Frequency: 15
# Word: protosebastos, Frequency: 2
# Word: matlin, Frequency: 1
# Word: demostration, Frequency: 1
# Word: ethelbald, Frequency: 4
# Word: draperies, Frequency: 3
# Word: classicized, Frequency: 1
# Word: farrar, Frequency: 31
# Word: dichotoma, Frequency: 3
# Word: standardised, Frequency: 42
# Word: reversals, Frequency: 9
# Word: kar, Frequency: 33
# Word: kandy, Frequency: 6
# Word: sauromatai, Frequency: 3
# Word: tocantins, Frequency: 14
# Word: spacelines, Frequency: 2
# Word: avita, Frequency: 4
# Word: longumeau, Frequency: 1
# Word: harpagophytum, Frequency: 1
# Word: strategoi, Frequency: 3
# Word: exhausts, Frequency: 12
# Word: hellenica, Frequency: 2
# Word: alberdi, Frequency: 1
# Word: barbie, Frequency: 44
# Word: ldskaparm, Frequency: 8
# Word: actia, Frequency: 2
# Word: seminars, Frequency: 30
# Word: javed, Frequency: 3
# Word: allophone, Frequency: 20
# Word: senegalensis, Frequency: 3
# Word: antelopes, Frequency: 5
# Word: archuleta, Frequency: 1
# Word: gallorum, Frequency: 2
# Word: ratifs, Frequency: 1
# Word: zebraskin, Frequency: 1
# Word: yagara, Frequency: 1
# Word: fluampicil, Frequency: 1
# Word: hijira, Frequency: 1
# Word: philanthropic, Frequency: 20
# Word: staked, Frequency: 5
# Word: assessors, Frequency: 7
# Word: intracontinental, Frequency: 1
# Word: fares, Frequency: 50
# Word: devastatingly, Frequency: 2
# Word: uriarra, Frequency: 1
# Word: flavio, Frequency: 6
# Word: abv, Frequency: 31
# Word: niza, Frequency: 2
# Word: sunshade, Frequency: 1
# Word: subsatellite, Frequency: 3
# Word: kentaurus, Frequency: 3
# Word: papingo, Frequency: 1
# Word: subantarctic, Frequency: 2
# Word: taniyama, Frequency: 7
# Word: patricius, Frequency: 3
# Word: ascetical, Frequency: 9
# Word: anabelian, Frequency: 2
# Word: growable, Frequency: 2
# Word: breaches, Frequency: 32
# Word: duplicating, Frequency: 13
# Word: pharoah, Frequency: 4
# Word: slavn, Frequency: 1
# Word: hagiography, Frequency: 9
# Word: scalable, Frequency: 30
# Word: rotations, Frequency: 40
# Word: rfastro, Frequency: 1
# Word: guitarists, Frequency: 121
# Word: systran, Frequency: 6
# Word: katyusha, Frequency: 26
# Word: sagoth, Frequency: 4
# Word: abdallah, Frequency: 14
# Word: hayat, Frequency: 6
# Word: solare, Frequency: 1
# Word: tazio, Frequency: 2
# Word: jafar, Frequency: 9
# Word: davidian, Frequency: 24
# Word: asper, Frequency: 2
# Word: argus, Frequency: 15
# Word: ensaimadas, Frequency: 1
# Word: memorias, Frequency: 1
# Word: taco, Frequency: 6
# Word: hasbro, Frequency: 34
# Word: souza, Frequency: 3
# Word: deployable, Frequency: 12
# Word: catecholamine, Frequency: 3
# Word: fasciculata, Frequency: 9
# Word: paediatric, Frequency: 3
# Word: deadlands, Frequency: 1
# Word: gustafson, Frequency: 3
# Word: dimethyltryptamine, Frequency: 6
# Word: achromatic, Frequency: 10
# Word: wlenca, Frequency: 1
# Word: chaykin, Frequency: 4
# Word: tirando, Frequency: 1
# Word: satavahanas, Frequency: 4
# Word: araku, Frequency: 1
# Word: citalopram, Frequency: 2
# Word: allocate, Frequency: 45
# Word: athlon, Frequency: 116
# Word: barbari, Frequency: 2
# Word: gameday, Frequency: 4
# Word: sonatensatzform, Frequency: 1
# Word: reharmonization, Frequency: 1
# Word: arrivant, Frequency: 1
# Word: damasio, Frequency: 8
# Word: defecation, Frequency: 8
# Word: aafk, Frequency: 4
# Word: hadendoa, Frequency: 1
# Word: hindquarters, Frequency: 4
# Word: senna, Frequency: 15
# Word: geraldo, Frequency: 4
# Word: haloperidol, Frequency: 5
# Word: enervating, Frequency: 2
# Word: autoeroticism, Frequency: 5
# Word: waldmeister, Frequency: 2
# Word: warfighting, Frequency: 3
# Word: nuptial, Frequency: 5
# Word: halbherr, Frequency: 1
# Word: epidaurus, Frequency: 2
# Word: indicarum, Frequency: 1
# Word: harman, Frequency: 12
# Word: pathos, Frequency: 9
# Word: constables, Frequency: 8
# Word: afium, Frequency: 1
# Word: altig, Frequency: 1
# Word: tadatsune, Frequency: 1
# Word: praj, Frequency: 3
# Word: kannur, Frequency: 3
# Word: pyridalization, Frequency: 1
# Word: farnborough, Frequency: 7
# Word: grattage, Frequency: 1
# Word: planepictures, Frequency: 1
# Word: overheats, Frequency: 2
# Word: mesocortical, Frequency: 1
# Word: osterach, Frequency: 1
# Word: ausgew, Frequency: 1
# Word: sparrowhawk, Frequency: 7
# Word: ferhat, Frequency: 1
# Word: disconfirmation, Frequency: 1
# Word: scheinermans, Frequency: 1
# Word: randt, Frequency: 3
# Word: nizari, Frequency: 3
# Word: qaed, Frequency: 1
# Word: harmfully, Frequency: 1
# Word: aucklandmap, Frequency: 1
# Word: redundantly, Frequency: 9
# Word: riverboat, Frequency: 13
# Word: tetrahydroaminoacridine, Frequency: 1
# Word: obliterated, Frequency: 12
# Word: persianized, Frequency: 1
# Word: lateline, Frequency: 2
# Word: aliasing, Frequency: 29
# Word: insat, Frequency: 1
# Word: streetcars, Frequency: 17
# Word: incorporations, Frequency: 1
# Word: redesignation, Frequency: 4
# Word: perugia, Frequency: 13
# Word: astartes, Frequency: 1
# Word: dignidad, Frequency: 2
# Word: aquarist, Frequency: 6
# Word: nearctic, Frequency: 3
# Word: swagmen, Frequency: 2
# Word: hagiographic, Frequency: 3
# Word: hydroxybenzaldehyde, Frequency: 1
# Word: usafammo, Frequency: 1
# Word: mazia, Frequency: 1
# Word: accoona, Frequency: 1
# Word: mineta, Frequency: 2
# Word: cafuzos, Frequency: 1
# Word: galinhas, Frequency: 1
# Word: vka, Frequency: 1
# Word: kandel, Frequency: 4
# Word: neognathae, Frequency: 3
# Word: culinarily, Frequency: 1
# Word: karrass, Frequency: 1
# Word: lackeys, Frequency: 1
# Word: banyan, Frequency: 10
# Word: plattd, Frequency: 3
# Word: martinal, Frequency: 1
# Word: dockyard, Frequency: 20
# Word: audiencia, Frequency: 7
# Word: neretva, Frequency: 3
# Word: doya, Frequency: 3
# Word: legwaila, Frequency: 1
# Word: oceanair, Frequency: 1
# Word: arly, Frequency: 1
# Word: assemblee, Frequency: 6
# Word: chiavenna, Frequency: 1
# Word: rehabilitate, Frequency: 8
# Word: flashdance, Frequency: 3
# Word: onbeats, Frequency: 1
# Word: arana, Frequency: 10
# Word: shave, Frequency: 20
# Word: korca, Frequency: 10
# Word: twat, Frequency: 3
# Word: calyculi, Frequency: 1
# Word: curveball, Frequency: 3
# Word: imicola, Frequency: 1
# Word: madhyamaka, Frequency: 6
# Word: guingand, Frequency: 2
# Word: auram, Frequency: 1
# Word: revocation, Frequency: 13
# Word: gangstas, Frequency: 1
# Word: amphiphilic, Frequency: 6
# Word: monografie, Frequency: 1
# Word: paramahamsa, Frequency: 2
# Word: trimbak, Frequency: 2
# Word: sagittal, Frequency: 4
# Word: hoaxing, Frequency: 5
# Word: ablik, Frequency: 1
# Word: bragarfull, Frequency: 2
# Word: doubledare, Frequency: 1
# Word: consecrating, Frequency: 4
# Word: alstom, Frequency: 6
# Word: defecane, Frequency: 1
# Word: chishona, Frequency: 1
# Word: demoralized, Frequency: 11
# Word: cacciapuoti, Frequency: 1
# Word: stace, Frequency: 2
# Word: apivorus, Frequency: 1
# Word: nitration, Frequency: 3
# Word: javier, Frequency: 31
# Word: cals, Frequency: 3
# Word: restarting, Frequency: 8
# Word: transgressionists, Frequency: 1
# Word: alphasyllabaries, Frequency: 1
# Word: thakurjhi, Frequency: 1
# Word: noornama, Frequency: 1
# Word: hoya, Frequency: 8
# Word: rani, Frequency: 3
# Word: dulhania, Frequency: 1
# Word: forehand, Frequency: 7
# Word: dispensations, Frequency: 7
# Word: dashes, Frequency: 17
# Word: kingair, Frequency: 1
# Word: kurzbach, Frequency: 1
# Word: myatt, Frequency: 2
# Word: reaffirmation, Frequency: 2
# Word: saggila, Frequency: 1
# Word: moabitess, Frequency: 2
# Word: husbandoid, Frequency: 1
# Word: hanley, Frequency: 3
# Word: fragonset, Frequency: 2
# Word: krabb, Frequency: 3
# Word: magjik, Frequency: 1
# Word: roadbed, Frequency: 1
# Word: agriotherium, Frequency: 1
# Word: extirpated, Frequency: 4
# Word: spainbearnews, Frequency: 1
# Word: teacup, Frequency: 3
# Word: materialise, Frequency: 6
# Word: marginals, Frequency: 1
# Word: harps, Frequency: 79
# Word: tyasamutp, Frequency: 1
# Word: verulamium, Frequency: 8
# Word: baburnama, Frequency: 4
# Word: defenestrated, Frequency: 1
# Word: helliconia, Frequency: 4
# Word: alphabetisation, Frequency: 2
# Word: vassily, Frequency: 7
# Word: lusatian, Frequency: 5
# Word: vaen, Frequency: 1
# Word: septentrinal, Frequency: 1
# Word: aggre, Frequency: 1
# Word: classicalliberalism, Frequency: 1
# Word: franken, Frequency: 13
# Word: batsuit, Frequency: 3
# Word: pinatubo, Frequency: 5
# Word: internalize, Frequency: 4
# Word: bacteriologists, Frequency: 2
# Word: yara, Frequency: 2
# Word: launder, Frequency: 4
# Word: wisecrack, Frequency: 4
# Word: madanapala, Frequency: 1
# Word: supernaturalization, Frequency: 1
# Word: massillon, Frequency: 3
# Word: vallentni, Frequency: 1
# Word: polychlorinated, Frequency: 4
# Word: frattarola, Frequency: 1
# Word: tradenames, Frequency: 1
# Word: ballysillan, Frequency: 2
# Word: poleglass, Frequency: 1
# Word: nae, Frequency: 3
# Word: lampreys, Frequency: 4
# Word: shatranj, Frequency: 2
# Word: barrens, Frequency: 3
# Word: rnaby, Frequency: 1
# Word: kebab, Frequency: 5
# Word: flashpoint, Frequency: 9
# Word: manitobans, Frequency: 5
# Word: bullhead, Frequency: 1
# Word: origial, Frequency: 1
# Word: artedi, Frequency: 2
# Word: reba, Frequency: 4
# Word: canntaireachd, Frequency: 1
# Word: autodetection, Frequency: 1
# Word: ahwahnee, Frequency: 1
# Word: tigay, Frequency: 2
# Word: gourane, Frequency: 1
# Word: albrighton, Frequency: 1
# Word: flocculants, Frequency: 1
# Word: uncompahgre, Frequency: 2
# Word: dorogomilovksian, Frequency: 1
# Word: daxiangguo, Frequency: 1
# Word: sonoran, Frequency: 8
# Word: barroso, Frequency: 10
# Word: negotiators, Frequency: 9
# Word: sultanates, Frequency: 9
# Word: caudillo, Frequency: 7
# Word: liberaci, Frequency: 6
# Word: kupjak, Frequency: 2
# Word: mornarica, Frequency: 1
# Word: plegaria, Frequency: 2
# Word: pentadactylos, Frequency: 1
# Word: lefkosia, Frequency: 2
# Word: electroencephalogram, Frequency: 3
# Word: evangelized, Frequency: 2
# Word: watercolours, Frequency: 2
# Word: executables, Frequency: 14
# Word: akamai, Frequency: 2
# Word: abrogans, Frequency: 2
# Word: baner, Frequency: 1
# Word: novoa, Frequency: 1
# Word: huerta, Frequency: 8
# Word: colonisations, Frequency: 2
# Word: biausa, Frequency: 1
# Word: milena, Frequency: 5
# Word: classfy, Frequency: 1
# Word: kaliski, Frequency: 3
# Word: multilanguage, Frequency: 1
# Word: mediately, Frequency: 1
# Word: spiritosa, Frequency: 1
# Word: paterno, Frequency: 2
# Word: contraccambio, Frequency: 1
# Word: alirio, Frequency: 1
# Word: ballina, Frequency: 4
# Word: eurasec, Frequency: 2
# Word: covariant, Frequency: 18
# Word: bassey, Frequency: 1
# Word: coolants, Frequency: 5
# Word: unabsorbed, Frequency: 1
# Word: peaberry, Frequency: 2
# Word: damor, Frequency: 1
# Word: neima, Frequency: 1
# Word: longmead, Frequency: 1
# Word: fundraisers, Frequency: 5
# Word: dieselisation, Frequency: 1
# Word: magnetised, Frequency: 1
# Word: factorially, Frequency: 1
# Word: bjarnarhaven, Frequency: 4
# Word: indeterminability, Frequency: 1
# Word: grolman, Frequency: 1
# Word: martan, Frequency: 2
# Word: ethanoate, Frequency: 1
# Word: basecamp, Frequency: 1
# Word: garfish, Frequency: 1
# Word: rheinseilbahn, Frequency: 1
# Word: saberhagen, Frequency: 12
# Word: votadini, Frequency: 6
# Word: rodellar, Frequency: 1
# Word: tashlin, Frequency: 3
# Word: mccrae, Frequency: 2
# Word: censura, Frequency: 1
# Word: quads, Frequency: 3
# Word: relearn, Frequency: 2
# Word: nassophorea, Frequency: 1
# Word: cranbrook, Frequency: 3
# Word: cachan, Frequency: 1
# Word: kaen, Frequency: 1
# Word: ilmenau, Frequency: 1
# Word: brahmos, Frequency: 1
# Word: jiujiang, Frequency: 1
# Word: raisonnable, Frequency: 2
# Word: cephalopoda, Frequency: 1
# Word: yesterdays, Frequency: 2
# Word: overpopulate, Frequency: 1
# Word: totamp, Frequency: 1
# Word: stacija, Frequency: 1
# Word: glandis, Frequency: 3
# Word: azia, Frequency: 4
# Word: plaisance, Frequency: 1
# Word: truespace, Frequency: 1
# Word: beranburh, Frequency: 2
# Word: parenting, Frequency: 17
# Word: spatha, Frequency: 1
# Word: laupen, Frequency: 2
# Word: elegantula, Frequency: 1
# Word: corbat, Frequency: 6
# Word: hudak, Frequency: 1
# Word: zhoutai, Frequency: 2
# Word: dimerization, Frequency: 1
# Word: bollards, Frequency: 2
# Word: grammatology, Frequency: 3
# Word: statuses, Frequency: 3
# Word: malfunctioning, Frequency: 8
# Word: lamothe, Frequency: 1
# Word: kulmerland, Frequency: 2
# Word: trypanosoma, Frequency: 12
# Word: triatominae, Frequency: 4
# Word: rbida, Frequency: 1
# Word: unrhetorical, Frequency: 1
# Word: yeastlike, Frequency: 1
# Word: windbreaker, Frequency: 1
# Word: avatiu, Frequency: 1
# Word: postapocalyptic, Frequency: 1
# Word: topotecan, Frequency: 2
# Word: orientalism, Frequency: 5
# Word: fenian, Frequency: 21
# Word: payoffs, Frequency: 19
# Word: namasyane, Frequency: 1
# Word: namelss, Frequency: 1
# Word: alburnus, Frequency: 1
# Word: schizothorax, Frequency: 1
# Word: oxygaster, Frequency: 1
# Word: repackage, Frequency: 2
# Word: hau, Frequency: 9
# Word: indubitably, Frequency: 3
# Word: mieszczanstwo, Frequency: 1
# Word: baheim, Frequency: 1
# Word: tzulah, Frequency: 1
# Word: ufurkan, Frequency: 1
# Word: atiscross, Frequency: 1
# Word: barch, Frequency: 1
# Word: vialli, Frequency: 5
# Word: sinalco, Frequency: 1
# Word: clanging, Frequency: 1
# Word: kalanlar, Frequency: 1
# Word: trammell, Frequency: 13
# Word: acutus, Frequency: 2
# Word: foramina, Frequency: 1
# Word: reframes, Frequency: 1
# Word: protolanguage, Frequency: 6
# Word: cleartype, Frequency: 55
# Word: reyna, Frequency: 7
# Word: cauda, Frequency: 2
# Word: marechal, Frequency: 1
# Word: replanted, Frequency: 1
# Word: rhipsalis, Frequency: 1
# Word: turbinicarpus, Frequency: 1
# Word: corpsprimary, Frequency: 1
# Word: litaf, Frequency: 1
# Word: moritani, Frequency: 2
# Word: mohiam, Frequency: 10
# Word: greatawaking, Frequency: 1
# Word: loleatta, Frequency: 1
# Word: cladoselache, Frequency: 1
# Word: santeria, Frequency: 5
# Word: graysmith, Frequency: 1
# Word: daalder, Frequency: 1
# Word: acridine, Frequency: 1
# Word: scarpetta, Frequency: 1
# Word: bodywatching, Frequency: 1
# Word: racinowski, Frequency: 1
# Word: basb, Frequency: 1
# Word: konkhra, Frequency: 1
# Word: deathmetal, Frequency: 1
# Word: usafv, Frequency: 1
# Word: cayler, Frequency: 1
# Word: iharire, Frequency: 1
# Word: ahriman, Frequency: 6
# Word: maitre, Frequency: 7
# Word: nameservers, Frequency: 6
# Word: graci, Frequency: 1
# Word: geminiani, Frequency: 1
# Word: paullu, Frequency: 1
# Word: bharathy, Frequency: 1
# Word: dativus, Frequency: 16
# Word: timeasia, Frequency: 1
# Word: streektalen, Frequency: 1
# Word: assaye, Frequency: 2
# Word: dhundia, Frequency: 1
# Word: exactitude, Frequency: 4
# Word: ustvolskaya, Frequency: 5
# Word: catma, Frequency: 2
# Word: daredevils, Frequency: 4
# Word: elucidator, Frequency: 1
# Word: ethnical, Frequency: 5
# Word: jamhuri, Frequency: 1
# Word: classmarks, Frequency: 2
# Word: humiliatrix, Frequency: 1
# Word: anushhthaatri, Frequency: 1
# Word: bhavedaadyah, Frequency: 1
# Word: brockman, Frequency: 2
# Word: caianiello, Frequency: 1
# Word: zoilam, Frequency: 1
# Word: havock, Frequency: 3
# Word: gurdwara, Frequency: 1
# Word: tda, Frequency: 2
# Word: charlet, Frequency: 1
# Word: bernanke, Frequency: 7
# Word: akrad, Frequency: 1
# Word: thelgar, Frequency: 1
# Word: machray, Frequency: 1
# Word: underplayed, Frequency: 2
# Word: kachina, Frequency: 1
# Word: draoiocht, Frequency: 1
# Word: conferance, Frequency: 1
# Word: bivariate, Frequency: 1
# Word: buhayrah, Frequency: 1
# Word: escwa, Frequency: 5
# Word: unrwa, Frequency: 11
# Word: caminemos, Frequency: 1
# Word: hamasen, Frequency: 1
# Word: harju, Frequency: 3
# Word: gojjam, Frequency: 3
# Word: dawa, Frequency: 3
# Word: benishangul, Frequency: 1
# Word: daf, Frequency: 8
# Word: kwaker, Frequency: 1
# Word: manchauggagogg, Frequency: 1
# Word: aakkram, Frequency: 1
# Word: strambach, Frequency: 1
# Word: epiphenomenalist, Frequency: 3
# Word: neurocomputational, Frequency: 1
# Word: turangal, Frequency: 2
# Word: ericaceous, Frequency: 1
# Word: telmatobius, Frequency: 2
# Word: horatius, Frequency: 2
# Word: stateswoman, Frequency: 2
# Word: dromaius, Frequency: 2
# Word: novazelandiae, Frequency: 1
# Word: kathablepharids, Frequency: 1
# Word: hedyphagetica, Frequency: 2
# Word: hysminai, Frequency: 1
# Word: terminators, Frequency: 2
# Word: azri, Frequency: 1
# Word: yasa, Frequency: 2
# Word: jankowski, Frequency: 4
# Word: llosa, Frequency: 5
# Word: ainsel, Frequency: 1
# Word: ezenarro, Frequency: 1
# Word: albizu, Frequency: 1
# Word: unactualized, Frequency: 1
# Word: khomani, Frequency: 2
# Word: okande, Frequency: 3
# Word: parthenogenetic, Frequency: 1
# Word: anaxicrates, Frequency: 1
# Word: osmanli, Frequency: 3
# Word: erasme, Frequency: 1
# Word: teotihuacano, Frequency: 1
# Word: constantini, Frequency: 2
# Word: jaht, Frequency: 1
# Word: vihjama, Frequency: 1
# Word: manguma, Frequency: 1
# Word: caballus, Frequency: 6
# Word: brenneria, Frequency: 1
# Word: vamos, Frequency: 1
# Word: dallamano, Frequency: 1
# Word: kaniff, Frequency: 1
# Word: norrath, Frequency: 6
# Word: parloff, Frequency: 1
# Word: nationalna, Frequency: 1
# Word: railgun, Frequency: 1
# Word: skywarrior, Frequency: 1
# Word: senka, Frequency: 6
# Word: ziusudra, Frequency: 2
# Word: superflat, Frequency: 1
# Word: cataplexy, Frequency: 3
# Word: webspace, Frequency: 1
# Word: kracauer, Frequency: 3
# Word: dodecahedrane, Frequency: 1
# Word: distributable, Frequency: 3
# Word: termaat, Frequency: 1
# Word: liliane, Frequency: 2
# Word: raux, Frequency: 3
# Word: nale, Frequency: 1
# Word: mangarevan, Frequency: 1
# Word: ghiat, Frequency: 1
# Word: tornedalen, Frequency: 1
# Word: gielaid, Frequency: 1
# Word: bartly, Frequency: 3
# Word: kashani, Frequency: 1
# Word: haradji, Frequency: 1
# Word: eanu, Frequency: 1
# Word: siepmann, Frequency: 2
# Word: breathable, Frequency: 7
# Word: reestablishes, Frequency: 1
# Word: parny, Frequency: 1
# Word: nationstate, Frequency: 1
# Word: hallenburg, Frequency: 1
# Word: beerawecka, Frequency: 1
# Word: paquets, Frequency: 1
# Word: raadt, Frequency: 1
# Word: eat
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# ivna, Frequency: 1
# Word: griqualand, Frequency: 1
# Word: fodera, Frequency: 2
# Word: crate, Frequency: 3
# Word: brailler, Frequency: 2
# Word: payen, Frequency: 3
# Word: donato, Frequency: 11
# Word: anteroom, Frequency: 1
# Word: unscriptural, Frequency: 1
# Word: brahman, Frequency: 74
# Word: kurita, Frequency: 1
# Word: giantess, Frequency: 16
# Word: universitaire, Frequency: 14
# Word: aspergillus, Frequency: 7
# Word: pisma, Frequency: 1
# Word: bila, Frequency: 5
# Word: deans, Frequency: 4
# Word: philermenian, Frequency: 1
# Word: shanahan, Frequency: 11
# Word: roseanne, Frequency: 7
# Word: camouflauge, Frequency: 1
# Word: batallions, Frequency: 3
# Word: bacteriostasis, Frequency: 1
# Word: hommages, Frequency: 1
# Word: urania, Frequency: 7
# Word: cadentis, Frequency: 1
# Word: bassoon, Frequency: 112
# Word: curtall, Frequency: 1
# Word: langwill, Frequency: 1
# Word: acclimatised, Frequency: 1
# Word: commentating, Frequency: 2
# Word: lauter, Frequency: 22
# Word: avit, Frequency: 1
# Word: zelma, Frequency: 1
# Word: fracas, Frequency: 5
# Word: wharves, Frequency: 4
# Word: vibrantly, Frequency: 2
# Word: traversals, Frequency: 2
# Word: abetted, Frequency: 3
# Word: imitators, Frequency: 26
# Word: junkballer, Frequency: 1
# Word: haggle, Frequency: 1
# Word: mithridates, Frequency: 5
# Word: counterattacked, Frequency: 3
# Word: alibekov, Frequency: 1
# Word: yekaterinburg, Frequency: 3
# Word: balak, Frequency: 2
# Word: helam, Frequency: 1
# Word: tremarctinae, Frequency: 1
# Word: ursinae, Frequency: 2
# Word: maritimus, Frequency: 2
# Word: silian, Frequency: 1
# Word: malagor, Frequency: 1
# Word: radiotherapy, Frequency: 11
# Word: pallares, Frequency: 1
# Word: rochdale, Frequency: 8
# Word: subareolar, Frequency: 2
# Word: fantasias, Frequency: 4
# Word: cantata, Frequency: 28
# Word: marceau, Frequency: 13
# Word: irreplaceable, Frequency: 11
# Word: domras, Frequency: 1
# Word: axions, Frequency: 2
# Word: diwan, Frequency: 7
# Word: taol, Frequency: 1
# Word: unaccelerated, Frequency: 2
# Word: jagdtiger, Frequency: 1
# Word: pansy, Frequency: 5
# Word: rhinopomatoidea, Frequency: 1
# Word: constrains, Frequency: 8
# Word: hamsa, Frequency: 1
# Word: sistan, Frequency: 4
# Word: afrikaniscker, Frequency: 1
# Word: sugical, Frequency: 1
# Word: organzing, Frequency: 1
# Word: navarra, Frequency: 4
# Word: paenibacillus, Frequency: 1
# Word: doable, Frequency: 1
# Word: goldwaters, Frequency: 1
# Word: nleutnant, Frequency: 6
# Word: bahl, Frequency: 1
# Word: technomage, Frequency: 2
# Word: wheatfield, Frequency: 2
# Word: alchoholic, Frequency: 2
# Word: qadr, Frequency: 2
# Word: labret, Frequency: 2
# Word: incarnated, Frequency: 6
# Word: radionuclides, Frequency: 6
# Word: geraci, Frequency: 1
# Word: jatoba, Frequency: 1
# Word: leaseholders, Frequency: 2
# Word: butka, Frequency: 1
# Word: korzhakov, Frequency: 3
# Word: manuk, Frequency: 1
# Word: energyaustralia, Frequency: 2
# Word: chiropractor, Frequency: 5
# Word: berryparadox, Frequency: 1
# Word: laganside, Frequency: 2
# Word: chatrang, Frequency: 1
# Word: arken, Frequency: 1
# Word: indiscrimination, Frequency: 1
# Word: semaphores, Frequency: 4
# Word: humaniores, Frequency: 2
# Word: heroica, Frequency: 1
# Word: carcharodon, Frequency: 1
# Word: mahabad, Frequency: 8
# Word: pluralistic, Frequency: 12
# Word: cabengo, Frequency: 1
# Word: colemak, Frequency: 1
# Word: schwarzbuch, Frequency: 1
# Word: comarques, Frequency: 3
# Word: euromosaic, Frequency: 3
# Word: luitgard, Frequency: 1
# Word: meritocratic, Frequency: 17
# Word: ablest, Frequency: 3
# Word: apomorphy, Frequency: 3
# Word: nanoelectromechanical, Frequency: 3
# Word: juans, Frequency: 1
# Word: brevibacterium, Frequency: 1
# Word: rainfalls, Frequency: 4
# Word: bakweri, Frequency: 1
# Word: macedo, Frequency: 3
# Word: adjusters, Frequency: 1
# Word: palacio, Frequency: 19
# Word: tonada, Frequency: 1
# Word: asilo, Frequency: 1
# Word: boatload, Frequency: 1
# Word: magdelaine, Frequency: 2
# Word: sanader, Frequency: 5
# Word: gotovac, Frequency: 1
# Word: venezuelans, Frequency: 2
# Word: escambray, Frequency: 1
# Word: coelurosaur, Frequency: 3
# Word: rainov, Frequency: 1
# Word: bartolomeu, Frequency: 5
# Word: beached, Frequency: 6
# Word: equant, Frequency: 1
# Word: artistical, Frequency: 1
# Word: sumanto, Frequency: 1
# Word: cyclopentadiene, Frequency: 5
# Word: varnishes, Frequency: 1
# Word: newspapering, Frequency: 2
# Word: lecturas, Frequency: 2
# Word: varities, Frequency: 1
# Word: utilitariansim, Frequency: 1
# Word: visaki, Frequency: 1
# Word: nati, Frequency: 2
# Word: barabas, Frequency: 1
# Word: vrtoglavica, Frequency: 1
# Word: apatista, Frequency: 1
# Word: tyrannicide, Frequency: 4
# Word: anthonid, Frequency: 1
# Word: toormakeady, Frequency: 1
# Word: necarne, Frequency: 1
# Word: raphical, Frequency: 1
# Word: nonvegetarians, Frequency: 2
# Word: chalet, Frequency: 3
# Word: frasier, Frequency: 100
# Word: damiens, Frequency: 3
# Word: chalcogens, Frequency: 3
# Word: housebreak, Frequency: 2
# Word: extemporaneous, Frequency: 4
# Word: retranslation, Frequency: 2
# Word: pastel, Frequency: 8
# Word: waqz, Frequency: 1
# Word: paycor, Frequency: 1
# Word: vaxcluster, Frequency: 3
# Word: achlmah, Frequency: 1
# Word: atwell, Frequency: 2
# Word: arpinum, Frequency: 2
# Word: partitionibus, Frequency: 1
# Word: backquote, Frequency: 3
# Word: inadvertant, Frequency: 2
# Word: alania, Frequency: 1
# Word: gravimetry, Frequency: 1
# Word: riphahn, Frequency: 1
# Word: lande, Frequency: 10
# Word: astrochicken, Frequency: 2
# Word: necromancers, Frequency: 12
# Word: subspaces, Frequency: 6
# Word: pedreiras, Frequency: 1
# Word: featurism, Frequency: 4
# Word: caboose, Frequency: 2
# Word: mcalpine, Frequency: 2
# Word: gomeisa, Frequency: 1
# Word: aridif, Frequency: 1
# Word: camoufler, Frequency: 1
# Word: restained, Frequency: 1
# Word: varistor, Frequency: 1
# Word: carm, Frequency: 1
# Word: acharya, Frequency: 12
# Word: cheongyang, Frequency: 1
# Word: nuestra, Frequency: 5
# Word: elizabethtown, Frequency: 5
# Word: hanzehogeschool, Frequency: 1
# Word: interstaatliche, Frequency: 1
# Word: kanto, Frequency: 6
# Word: kwangju, Frequency: 2
# Word: marymount, Frequency: 4
# Word: gesamthochschule, Frequency: 2
# Word: rovira, Frequency: 4
# Word: cruach, Frequency: 1
# Word: bassin, Frequency: 2
# Word: weathermen, Frequency: 2
# Word: konstantinos, Frequency: 8
# Word: kasay, Frequency: 6
# Word: crossman, Frequency: 5
# Word: antipatharia, Frequency: 1
# Word: scyphomedusae, Frequency: 1
# Word: fedaykin, Frequency: 1
# Word: axeman, Frequency: 1
# Word: ghola, Frequency: 24
# Word: mutualistic, Frequency: 1
# Word: jiddispja, Frequency: 1
# Word: sardu, Frequency: 3
# Word: pharasaic, Frequency: 1
# Word: dabru, Frequency: 1
# Word: thusfar, Frequency: 1
# Word: pickard, Frequency: 10
# Word: culpaeus, Frequency: 1
# Word: aridness, Frequency: 1
# Word: cynvael, Frequency: 1
# Word: nakamura, Frequency: 12
# Word: mamelukes, Frequency: 2
# Word: tarraco, Frequency: 1
# Word: brevistyla, Frequency: 1
# Word: azriel, Frequency: 2
# Word: cyborgation, Frequency: 1
# Word: yaoguang, Frequency: 1
# Word: flanner, Frequency: 1
# Word: kabalevsky, Frequency: 3
# Word: photomicrograph, Frequency: 1
# Word: metabolically, Frequency: 6
# Word: anthrenus, Frequency: 2
# Word: candyfreak, Frequency: 1
# Word: carlingford, Frequency: 3
# Word: dewar, Frequency: 34
# Word: seacliffs, Frequency: 1
# Word: teuta, Frequency: 2
# Word: partholon, Frequency: 1
# Word: cartographic, Frequency: 28
# Word: buckintoopa, Frequency: 1
# Word: madision, Frequency: 1
# Word: crankshafts, Frequency: 13
# Word: casteist, Frequency: 1
# Word: sidamo, Frequency: 3
# Word: importace, Frequency: 1
# Word: scandola, Frequency: 1
# Word: fahn, Frequency: 1
# Word: wakamoto, Frequency: 1
# Word: matsuda, Frequency: 5
# Word: arminta, Frequency: 2
# Word: structuralists, Frequency: 2
# Word: exegetical, Frequency: 17
# Word: rachamecha, Frequency: 1
# Word: masarta, Frequency: 1
# Word: adasa, Frequency: 1
# Word: monochromacy, Frequency: 7
# Word: anomaloscope, Frequency: 2
# Word: dubstar, Frequency: 1
# Word: dayborne, Frequency: 1
# Word: logographs, Frequency: 2
# Word: biomagnified, Frequency: 1
# Word: pasterka, Frequency: 1
# Word: commenda, Frequency: 1
# Word: magdi, Frequency: 1
# Word: innertraditions, Frequency: 1
# Word: viena, Frequency: 1
# Word: undiplomatically, Frequency: 1
# Word: aittojoki, Frequency: 2
# Word: solovay, Frequency: 1
# Word: namor, Frequency: 4
# Word: cholla, Frequency: 1
# Word: abcabcabc, Frequency: 1
# Word: cattleman, Frequency: 2
# Word: rephrasings, Frequency: 1
# Word: majstro, Frequency: 3
# Word: homonuclear, Frequency: 3
# Word: amfissa, Frequency: 1
# Word: ssdna, Frequency: 2
# Word: ibanex, Frequency: 2
# Word: klowdan, Frequency: 2
# Word: medarabtel, Frequency: 5
# Word: disdyakis, Frequency: 1
# Word: arthurdent, Frequency: 1
# Word: jazzstep, Frequency: 1
# Word: monastical, Frequency: 1
# Word: enterainment, Frequency: 1
# Word: caprifoliaceae, Frequency: 2
# Word: rhaeto, Frequency: 5
# Word: barnstaple, Frequency: 4
# Word: quale, Frequency: 6
# Word: residuals, Frequency: 24
# Word: berall, Frequency: 1
# Word: zhifang, Frequency: 1
# Word: sabina, Frequency: 12
# Word: kabalistical, Frequency: 2
# Word: gigaset, Frequency: 1
# Word: mazzi, Frequency: 2
# Word: savor, Frequency: 3
# Word: naraka, Frequency: 3
# Word: hrungstransformationen, Frequency: 1
# Word: cagney, Frequency: 27
# Word: maes, Frequency: 4
# Word: paramagnets, Frequency: 1
# Word: kupang, Frequency: 2
# Word: dufaure, Frequency: 2
# Word: aldea, Frequency: 1
# Word: arbo, Frequency: 1
# Word: trapezoids, Frequency: 2
# Word: tameru, Frequency: 1
# Word: zarbon, Frequency: 2
# Word: karla, Frequency: 3
# Word: portual, Frequency: 1
# Word: piebald, Frequency: 4
# Word: auraria, Frequency: 2
# Word: pastels, Frequency: 3
# Word: aaronid, Frequency: 2
# Word: bevacqua, Frequency: 1
# Word: diasporic, Frequency: 1
# Word: spaniels, Frequency: 1
# Word: akbash, Frequency: 1
# Word: stda, Frequency: 1
# Word: homogeneisation, Frequency: 1
# Word: mangosteens, Frequency: 1
# Word: nagado, Frequency: 3
# Word: bachi, Frequency: 3
# Word: gambale, Frequency: 1
# Word: grale, Frequency: 1
# Word: parsestring, Frequency: 1
# Word: apprehending, Frequency: 4
# Word: postdoctorate, Frequency: 1
# Word: bursary, Frequency: 1
# Word: viacheslav, Frequency: 2
# Word: casque, Frequency: 1
# Word: medicinae, Frequency: 2
# Word: lambertus, Frequency: 1
# Word: bromhead, Frequency: 1
# Word: streampipe, Frequency: 1
# Word: kumarikhandam, Frequency: 1
# Word: relagated, Frequency: 1
# Word: lagua, Frequency: 1
# Word: iosheka, Frequency: 1
# Word: pearly, Frequency: 7
# Word: simulans, Frequency: 1
# Word: carpe, Frequency: 5
# Word: coleraine, Frequency: 2
# Word: durkan, Frequency: 2
# Word: goorkhas, Frequency: 1
# Word: marengo, Frequency: 2
# Word: microcapsules, Frequency: 2
# Word: kohlhaase, Frequency: 1
# Word: neuginea, Frequency: 1
# Word: nanoengineering, Frequency: 1
# Word: itihaas, Frequency: 1
# Word: aibling, Frequency: 1
# Word: indefinable, Frequency: 6
# Word: englandearly, Frequency: 1
# Word: xyridales, Frequency: 2
# Word: dollarization, Frequency: 5
# Word: machala, Frequency: 1
# Word: aleem, Frequency: 1
# Word: hokouma, Frequency: 1
# Word: sabahi, Frequency: 1
# Word: motagua, Frequency: 4
# Word: rva, Frequency: 1
# Word: aestii, Frequency: 2
# Word: abreha, Frequency: 1
# Word: rossiada, Frequency: 1
# Word: lsunga, Frequency: 4
# Word: eurohacker, Frequency: 1
# Word: paleoanthropological, Frequency: 3
# Word: manditory, Frequency: 2
# Word: basevg, Frequency: 3
# Word: kafkas, Frequency: 1
# Word: innoculated, Frequency: 1
# Word: abled, Frequency: 2
# Word: bowdlerisation, Frequency: 1
# Word: margheriti, Frequency: 2
# Word: myopica, Frequency: 1
# Word: macclintocki, Frequency: 1
# Word: bernician, Frequency: 1
# Word: interchanging, Frequency: 5
# Word: nacpec, Frequency: 1
# Word: jaqua, Frequency: 1
# Word: behavorial, Frequency: 1
# Word: biomasses, Frequency: 4
# Word: tanar, Frequency: 1
# Word: assayer, Frequency: 2
# Word: washings, Frequency: 1
# Word: llenlleawg, Frequency: 1
# Word: rodericana, Frequency: 2
# Word: miyakoensis, Frequency: 1
# Word: turnagra, Frequency: 2
# Word: maildir, Frequency: 4
# Word: magocracy, Frequency: 1
# Word: kratas, Frequency: 1
# Word: nasda, Frequency: 2
# Word: spirochaete, Frequency: 1
# Word: diplomonads, Frequency: 1
# Word: classica, Frequency: 1
# Word: handcuffed, Frequency: 4
# Word: apasa, Frequency: 1
# Word: liberali, Frequency: 1
# Word: subrack, Frequency: 7
# Word: iradi, Frequency: 1
# Word: annemarie, Frequency: 2
# Word: naxi, Frequency: 3
# Word: adversly, Frequency: 1
# Word: strats, Frequency: 2
# Word: cohabitated, Frequency: 1
# Word: zaches, Frequency: 1
# Word: protodeacons, Frequency: 1
# Word: tantsima, Frequency: 1
# Word: plass, Frequency: 2
# Word: piovra, Frequency: 6
# Word: cristallo, Frequency: 1
# Word: osami, Frequency: 2
# Word: persica, Frequency: 3
# Word: belaruskaja, Frequency: 1
# Word: kaika, Frequency: 4
# Word: karahime, Frequency: 1
# Word: sugawara, Frequency: 2
# Word: methodologically, Frequency: 3
# Word: fasciculation, Frequency: 1
# Word: confederalism, Frequency: 2
# Word: organiques, Frequency: 1
# Word: languagehelpers, Frequency: 1
# Word: aniko, Frequency: 1
# Word: panova, Frequency: 2
# Word: communitaire, Frequency: 1
# Word: tunas, Frequency: 1
# Word: bonnaire, Frequency: 2
# Word: achard, Frequency: 3
# Word: graycliff, Frequency: 2
# Word: bleaker, Frequency: 3
# Word: morainic, Frequency: 4
# Word: copylaw, Frequency: 1
# Word: berardinelli, Frequency: 2
# Word: ryazanov, Frequency: 2
# Word: morando, Frequency: 3
# Word: naushika, Frequency: 1
# Word: nummenaho, Frequency: 1
# Word: arteriosum, Frequency: 2
# Word: romanesco, Frequency: 1
# Word: aidc, Frequency: 2
# Word: olesha, Frequency: 2
# Word: misquotation, Frequency: 2
# Word: lackington, Frequency: 1
# Word: sicurezza, Frequency: 5
# Word: gibaut, Frequency: 1
# Word: neaman, Frequency: 2
# Word: maffei, Frequency: 16
# Word: dohnanyi, Frequency: 4
# Word: superfast, Frequency: 3
# Word: apperard, Frequency: 1
# Word: beasant, Frequency: 2
# Word: ngaedhael, Frequency: 3
# Word: madani, Frequency: 1
# Word: nordica, Frequency: 1
# Word: elastically, Frequency: 1
# Word: defrauded, Frequency: 2
# Word: fructarians, Frequency: 1
# Word: bdpa, Frequency: 1
# Word: xvga, Frequency: 1
# Word: cepstra, Frequency: 1
# Word: halgol, Frequency: 1
# Word: nataliya, Frequency: 3
# Word: zackie, Frequency: 1
# Word: kamaphitha, Frequency: 1
# Word: antinutrients, Frequency: 1
# Word: scarantino, Frequency: 1
# Word: lancastre, Frequency: 1
# Word: interpolationis, Frequency: 1
# Word: casevac, Frequency: 1
# Word: intransigence, Frequency: 2
# Word: jammer, Frequency: 5
# Word: harmonist, Frequency: 1
# Word: articulators, Frequency: 1
# Word: disembarkment, Frequency: 1
# Word: mistreat, Frequency: 1
# Word: mnas, Frequency: 1
# Word: strake, Frequency: 1
# Word: manipuled, Frequency: 1
# Word: amanuel, Frequency: 1
# Word: kanwar, Frequency: 1
# Word: hermannsdenkmal, Frequency: 1
# Word: saggiatore, Frequency: 1
# Word: relearned, Frequency: 1
# Word: modelmaking, Frequency: 1
# Word: tsuda, Frequency: 2
# Word: sunyani, Frequency: 1
# Word: asantehene, Frequency: 3
# Word: akwapim, Frequency: 7
# Word: jmiasto, Frequency: 2
# Word: lyrestad, Frequency: 1
# Word: stablemates, Frequency: 2
# Word: historicallz, Frequency: 1
# Word: arz, Frequency: 5
# Word: macenta, Frequency: 1
# Word: mazaruni, Frequency: 1
# Word: enschlag, Frequency: 1
# Word: nahmen, Frequency: 1
# Word: busman, Frequency: 10
# Word: sturtian, Frequency: 1
# Word: sunspear, Frequency: 1
# Word: natpisi, Frequency: 1
# Word: interlayer, Frequency: 1
# Word: glissandoing, Frequency: 1
# Word: amstrup, Frequency: 1
# Word: meaney, Frequency: 2
# Word: silivas, Frequency: 1
# Word: sessina, Frequency: 1
# Word: zyad, Frequency: 1
# Word: takehito, Frequency: 1
# Word: axiome, Frequency: 1
# Word: islamico, Frequency: 1
# Word: sacromonte, Frequency: 1
# Word: rasi, Frequency: 2
# Word: apfelsaftschorle, Frequency: 1
# Word: whatissoaring, Frequency: 1
# Word: gautoz, Frequency: 2
# Word: altertumsforschung, Frequency: 1
# Word: hmittelalterlichen, Frequency: 1
# Word: katoa, Frequency: 2
# Word: energa, Frequency: 1
# Word: cisowa, Frequency: 1
# Word: converage, Frequency: 1
# Word: ouwater, Frequency: 2
# Word: bruckmann, Frequency: 1
# Word: proliferance, Frequency: 1
# Word: andare, Frequency: 2
# Word: pyran, Frequency: 2
# Word: dantis, Frequency: 1
# Word: laborit, Frequency: 1
# Word: zeka, Frequency: 1
# Word: garfields, Frequency: 1
# Word: istinja, Frequency: 1
# Word: balari, Frequency: 2
# Word: cassegrain, Frequency: 3
# Word: earthwoman, Frequency: 1
# Word: waterpolo, Frequency: 2
# Word: tosakin, Frequency: 1
# Word: discordance, Frequency: 4
# Word: cumulates, Frequency: 1
# Word: everard, Frequency: 4
# Word: tasini, Frequency: 2
# Word: gailard, Frequency: 1
# Word: achterhuis, Frequency: 1
# Word: zumalac, Frequency: 3
# Word: nobla, Frequency: 1
# Word: narkompros, Frequency: 2
# Word: hazaq, Frequency: 3
# Word: kurzfilmfestival, Frequency: 1
# Word: blackamoores, Frequency: 1
# Word: earliness, Frequency: 1
# Word: marxmyths, Frequency: 2
# Word: zachery, Frequency: 2
# Word: inaccessa, Frequency: 1
# Word: causalit, Frequency: 1
# Word: cerveau, Frequency: 3
# Word: samachar, Frequency: 2
# Word: adjudicator, Frequency: 1
# Word: ceann, Frequency: 3
# Word: grulla, Frequency: 1
# Word: premchand, Frequency: 2
# Word: findtwinprimeabove, Frequency: 1
# Word: unbacked, Frequency: 1
# Word: laris, Frequency: 3
# Word: hilbasis, Frequency: 1
# Word: carnegiefoundation, Frequency: 1
# Word: haddith, Frequency: 1
# Word: iconclasts, Frequency: 1
# Word: maginnes, Frequency: 1
# Word: maidah, Frequency: 1
# Word: aihe, Frequency: 1
# Word: khushal, Frequency: 1
# Word: invalidly, Frequency: 2
# Word: marshimot, Frequency: 1
# Word: barkiyaruq, Frequency: 1
# Word: meanz, Frequency: 2
# Word: austurvegi, Frequency: 1
# Word: salzedo, Frequency: 3
# Word: haniya, Frequency: 3
# Word: sharezer, Frequency: 1
# Word: ryabushkin, Frequency: 1
# Word: bautzen, Frequency: 2
# Word: lamos, Frequency: 2
# Word: seatbone, Frequency: 1
# Word: natrum, Frequency: 1
# Word: anthroposophically, Frequency: 1
# Word: admoni, Frequency: 1
# Word: sophisticate, Frequency: 2
# Word: caerwiden, Frequency: 1
# Word: mathilda, Frequency: 3
# Word: titaness, Frequency: 3
# Word: uusikaupunki, Frequency: 1
# Word: ruah, Frequency: 2
# Word: adduct, Frequency: 1
# Word: featural, Frequency: 4
# Word: gurbani, Frequency: 1
# Word: purandaradasa, Frequency: 2
# Word: muhammadur, Frequency: 1
# Word: qadar, Frequency: 1
# Word: sabilillah, Frequency: 4
# Word: ibadhism, Frequency: 1
# Word: gloriad, Frequency: 1
# Word: amautiit, Frequency: 1
# Word: chenab, Frequency: 3
# Word: adrc, Frequency: 1
# Word: milad, Frequency: 1
# Word: gravellona, Frequency: 1
# Word: arrivederci, Frequency: 1
# Word: iipa, Frequency: 2
# Word: loaghtan, Frequency: 1
# Word: crossbarry, Frequency: 1
# Word: atheros, Frequency: 2
# Word: substantiating, Frequency: 1
# Word: billingstad, Frequency: 1
# Word: massachutsetts, Frequency: 1
# Word: riyad, Frequency: 1
# Word: akua, Frequency: 1
# Word: khasawneh, Frequency: 1
# Word: garganelli, Frequency: 1
# Word: incertae, Frequency: 2
# Word: wasserl, Frequency: 1
# Word: ithacan, Frequency: 6
# Word: smallisbeautiful, Frequency: 1
# Word: aluminados, Frequency: 1
# Word: faruqi, Frequency: 2
# Word: iala, Frequency: 21
# Word: helpar, Frequency: 1
# Word: rdna, Frequency: 4
# Word: tuscarora, Frequency: 2
# Word: sanctificate, Frequency: 1
# Word: ribavirin, Frequency: 4
# Word: kambula, Frequency: 2
# Word: staffin, Frequency: 2
# Word: interna, Frequency: 1
# Word: nating, Frequency: 2
# Word: pacaka, Frequency: 1
# Word: alcoves, Frequency: 1
# Word: cuchaillin, Frequency: 1
# Word: sulfamethazine, Frequency: 1
# Word: paludrine, Frequency: 1
# Word: alterum, Frequency: 2
# Word: talkdesign, Frequency: 3
# Word: ashtaha, Frequency: 1
# Word: karategi, Frequency: 1
# Word: paatii, Frequency: 1
# Word: masayoshi, Frequency: 4
# Word: tzmann, Frequency: 1
# Word: cathedralis, Frequency: 1
# Word: decani, Frequency: 1
# Word: zusammenbruchs, Frequency: 1
# Word: payadas, Frequency: 1
# Word: walch, Frequency: 2
# Word: vassell, Frequency: 1
# Word: hodiak, Frequency: 1
# Word: inab, Frequency: 1
# Word: sampoong, Frequency: 1
# Word: alekseyevna, Frequency: 1
# Word: haligonians, Frequency: 1
# Word: arrangmenet, Frequency: 1
# Word: hispaniensis, Frequency: 1
# Word: knightage, Frequency: 1
# Word: bainton, Frequency: 3
# Word: fairley, Frequency: 1
# Word: kassebaum, Frequency: 1
# Word: tahmasb, Frequency: 1
# Word: monzaemon, Frequency: 2
# Word: ratcatcher, Frequency: 2
# Word: grahovopolje, Frequency: 1
# Word: gatsio, Frequency: 1
# Word: kareit, Frequency: 1
# Word: homestar, Frequency: 1
# Word: hidayah, Frequency: 1
# Word: melanistic, Frequency: 2
# Word: acquaintanceship, Frequency: 1
# Word: lactoridaceae, Frequency: 2
# Word: coweta, Frequency: 1
# Word: baas, Frequency: 2
# Word: vandar, Frequency: 1
# Word: tacchinardi, Frequency: 1
# Word: pesiqta, Frequency: 5
# Word: bayqongyr, Frequency: 7
# Word: atirau, Frequency: 1
# Word: qarakhanids, Frequency: 2
# Word: gravest, Frequency: 2
# Word: lukarco, Frequency: 1
# Word: gettingaround, Frequency: 1
# Word: arfaj, Frequency: 1
# Word: yourgrau, Frequency: 1
# Word: hanguk, Frequency: 2
# Word: subglottal, Frequency: 1
# Word: haejangguk, Frequency: 2
# Word: aurthurian, Frequency: 1
# Word: iqta, Frequency: 1
# Word: zenigata, Frequency: 1
# Word: funpaira, Frequency: 1
# Word: sackheim, Frequency: 1
# Word: treifa, Frequency: 1
# Word: kainite, Frequency: 1
# Word: jidai, Frequency: 2
# Word: kociewiacy, Frequency: 1
# Word: atsumi, Frequency: 3
# Word: pandaravasini, Frequency: 1
# Word: sak, Frequency: 2
# Word: stranb, Frequency: 1
# Word: thomman, Frequency: 1
# Word: eduardovich, Frequency: 2
# Word: timboroa, Frequency: 1
# Word: kayoed, Frequency: 1
# Word: bootsmansrots, Frequency: 1
# Word: kettlebarston, Frequency: 1
# Word: vassalaged, Frequency: 1
# Word: organiz, Frequency: 1
# Word: angwantibo, Frequency: 2
# Word: notaire, Frequency: 4
# Word: waveguiding, Frequency: 1
# Word: ghdamis, Frequency: 1
# Word: ripogonaceae, Frequency: 1
# Word: liasons, Frequency: 1
# Word: louangphrabang, Frequency: 1
# Word: steadied, Frequency: 2
# Word: chehab, Frequency: 1
# Word: weah, Frequency: 1
# Word: investitional, Frequency: 1
# Word: kurzamra, Frequency: 1
# Word: jagdgruppe, Frequency: 1
# Word: thrombocytopenia, Frequency: 2
# Word: spanley, Frequency: 1
# Word: smena, Frequency: 1
# Word: narga, Frequency: 1
# Word: sdays, Frequency: 1
# Word: faciet, Frequency: 1
# Word: faciatis, Frequency: 1
# Word: fiebatis, Frequency: 1
# Word: candaules, Frequency: 3
# Word: mamilius, Frequency: 1
# Word: standoffish, Frequency: 1
# Word: caterina, Frequency: 8
# Word: calum, Frequency: 1
# Word: juchereau, Frequency: 1
# Word: foward, Frequency: 1
# Word: naperville, Frequency: 1
# Word: pygopodidae, Frequency: 1
# Word: cordylidae, Frequency: 1
# Word: jayabaya, Frequency: 1
# Word: samy, Frequency: 1
# Word: govindsvamin, Frequency: 1
# Word: shivdasani, Frequency: 1
# Word: sivaji, Frequency: 1
# Word: danys, Frequency: 1
# Word: adjunction, Frequency: 1
# Word: behavioralism, Frequency: 1
# Word: waywalkers, Frequency: 1
# Word: intrasome, Frequency: 1
# Word: apochromat, Frequency: 1
# Word: carboxylase, Frequency: 1
# Word: hartson, Frequency: 2
# Word: baltikum, Frequency: 2
# Word: pleura, Frequency: 2
# Word: naistithe, Frequency: 1
# Word: pastorate, Frequency: 3
# Word: pelasgiotis, Frequency: 1
# Word: categoriser, Frequency: 1
# Word: kaltim, Frequency: 1
# Word: uryadovy, Frequency: 1
# Word: haxxored, Frequency: 1
# Word: walesa, Frequency: 8
# Word: pfaffenberger, Frequency: 1
# Word: larochelle, Frequency: 1
# Word: halfin, Frequency: 3
# Word: alternica, Frequency: 1
# Word: summerslam, Frequency: 1
# Word: sleepwalks, Frequency: 1
# Word: berasategui, Frequency: 1
# Word: hazrat, Frequency: 6
# Word: piperascens, Frequency: 1
# Word: synaptonemal, Frequency: 3
# Word: spermatogonia, Frequency: 1
# Word: negima, Frequency: 1
# Word: suburbano, Frequency: 1
# Word: ohrida, Frequency: 1
# Word: nonformal, Frequency: 1
# Word: ajouhu, Frequency: 1
# Word: kanheri, Frequency: 2
# Word: boisadam, Frequency: 1
# Word: eurocreditbank, Frequency: 1
# Word: chiparus, Frequency: 1
# Word: geralds, Frequency: 1
# Word: interplays, Frequency: 2
# Word: leath, Frequency: 2
# Word: khudai, Frequency: 1
# Word: maimonideans, Frequency: 2
# Word: tiae, Frequency: 1
# Word: mishaic, Frequency: 1
# Word: contractible, Frequency: 1
# Word: mekhilta, Frequency: 7
# Word: articulorum, Frequency: 1
# Word: metamonads, Frequency: 1
# Word: redwater, Frequency: 1
# Word: comgall, Frequency: 1
# Word: donnall, Frequency: 1
# Word: granberg, Frequency: 2
# Word: doriva, Frequency: 1
# Word: gachet, Frequency: 1
# Word: dympna, Frequency: 2
# Word: bambuti, Frequency: 1
# Word: tangia, Frequency: 1
# Word: ghzal, Frequency: 1
# Word: ripudaman, Frequency: 1
# Word: calendimaggio, Frequency: 1
# Word: lajaa, Frequency: 1
# Word: olecular, Frequency: 2
# Word: landino, Frequency: 1
# Word: mesda, Frequency: 1
# Word: cnmat, Frequency: 1
# Word: gonward, Frequency: 1
# Word: miryam, Frequency: 4
# Word: atrani, Frequency: 2
# Word: puffball, Frequency: 1
# Word: znamennoe, Frequency: 2
# Word: kasztner, Frequency: 1
# Word: sphagnum, Frequency: 1
# Word: lowballed, Frequency: 1
# Word: iradio, Frequency: 1
# Word: zlatko, Frequency: 2
# Word: nbma, Frequency: 1
# Word: abnehmend, Frequency: 1
# Word: sarangani, Frequency: 3
# Word: ambac, Frequency: 3
# Word: saidy, Frequency: 1
# Word: carmello, Frequency: 1
# Word: colomba, Frequency: 1
# Word: generical, Frequency: 1
# Word: mantovani, Frequency: 1
# Word: dawakhanaa, Frequency: 1
# Word: sloas, Frequency: 2
# Word: vanhorne, Frequency: 1
# Word: alexanderwohl, Frequency: 1
# Word: samul, Frequency: 1
# Word: wingflap, Frequency: 1
# Word: alanic, Frequency: 1
# Word: bhau, Frequency: 2
# Word: mirae, Frequency: 1
# Word: stealhy, Frequency: 1
# Word: salicrup, Frequency: 1
# Word: gennadi, Frequency: 1

# %% [markdown]
# • DataFrame Task: Create a Spark dataframe using the iris json data mentioned above. Calculate Pearson Correlation between the columns petalLength and petalWidth using the appropriate dataframe API. Show the columns sepalLength, sepalWidth and species for the rows of data that has petalLength greater than or equal to 1.4 using the appropriate dataframe API.

# %%
from pyspark.sql.functions import corr

# %%
# Read iris JSON data into a Spark DataFrame
iris = spark.read.json("dbfs:/FileStore/shared_uploads/202318044@daiict.ac.in/iris-2.json")
iris
# Calculate Pearson Correlation between petalLength and petalWidth
pearson_corr = iris.select(corr("petalLength", "petalWidth")).collect()[0][0]
print("Pearson correlation between petalLength and petalWidth is :", pearson_corr)
# Out:
# Pearson correlation between petalLength and petalWidth is : 0.962865431402796

# %%
data1 = iris.filter(iris["petalLength"] >= 1.4).select(iris["sepalLength"], iris["sepalWidth"], iris["species"])
data1.show()
# Out:
# +-----------+----------+-------+
# |sepalLength|sepalWidth|species|
# +-----------+----------+-------+
# |        5.1|       3.5| setosa|
# |        4.9|       3.0| setosa|
# |        4.6|       3.1| setosa|
# |        5.0|       3.6| setosa|
# |        5.4|       3.9| setosa|
# |        4.6|       3.4| setosa|
# |        5.0|       3.4| setosa|
# |        4.4|       2.9| setosa|
# |        4.9|       3.1| setosa|
# |        5.4|       3.7| setosa|
# |        4.8|       3.4| setosa|
# |        4.8|       3.0| setosa|
# |        5.7|       4.4| setosa|
# |        5.1|       3.5| setosa|
# |        5.7|       3.8| setosa|
# |        5.1|       3.8| setosa|
# |        5.4|       3.4| setosa|
# |        5.1|       3.7| setosa|
# |        5.1|       3.3| setosa|
# |        4.8|       3.4| setosa|
# +-----------+----------+-------+
# only showing top 20 rows
